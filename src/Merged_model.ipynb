# %% [markdown]
# # Prepare environment

# %%
# !pip install albumentations --user > /dev/null 2>&1

# %%
# !pip install pretrainedmodels --user > /dev/null 2>&1

# %%
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
import matplotlib.image as mplimg
from matplotlib.pyplot import imshow

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

import torch
from torch.utils.data import TensorDataset, DataLoader,Dataset
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import torch.optim as optim
from torch.optim import lr_scheduler
import time 
import tqdm
from PIL import Image
train_on_gpu = True
from torch.utils.data.sampler import SubsetRandomSampler
from torch.optim.lr_scheduler import StepLR, ReduceLROnPlateau, CosineAnnealingLR

import warnings
warnings.simplefilter("ignore", category=DeprecationWarning)

from collections import OrderedDict
import cv2
import albumentations
from albumentations import torch as AT
import pretrainedmodels
import csv
from sklearn.neighbors import KNeighborsClassifier
from torch.autograd import Variable
from torchvision.utils import save_image
from sklearn.externals import joblib
from sklearn.svm import LinearSVC
from torchvision import models

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %% [markdown]
# # Prepare data

# %%
train_df = pd.read_csv("./train.csv")
train_df.head()
# Out:
#            Image         Id
# 0  b4284d5ef.jpg  w_16b5050
# 1  4b82a9fc0.jpg  new_whale
# 2  16bf136fb.jpg  w_e73cce3
# 3  9805abc71.jpg  w_d6fde02
# 4  4e2803603.jpg  w_83a4279

# %%
train_df.Id.value_counts().head()
# Out:
# new_whale    7728
# w_23a388d      60
# w_9b5109b      55
# w_0369a5c      54
# w_9c506f6      52
# Name: Id, dtype: int64

# %%
train_df = train_df[~(train_df.Id == "new_whale")]
train_df.Id.value_counts().head()
# Out:
# w_23a388d    60
# w_9b5109b    55
# w_0369a5c    54
# w_9c506f6    52
# w_700ebb4    46
# Name: Id, dtype: int64

# %%
test_df = pd.read_csv("./new_whale_test.csv")

# %%
print(f"There are {len(os.listdir('./whaletrain'))} images in train dataset with {train_df.Id.nunique()} unique classes.")
#print(f"There are {len(os.listdir('../data/test'))} images in test dataset with {test_df.Id.nunique()} unique classes.")
# Out:
# There are 20288 images in train dataset with 4571 unique classes.

# %%
for i in range(1, 4):
    print(f'There are {train_df.Id.value_counts()[train_df.Id.value_counts().values==i].shape[0]} classes with {i} samples in train data.')
# Out:
# There are 2182 classes with 1 samples in train data.
# There are 1085 classes with 2 samples in train data.
# There are 441 classes with 3 samples in train data.

# %%
len(train_df.Id)
# Out:
# 20288

# %%
train_df.Id.value_counts()[1:].plot(kind='hist');
plt.title('Distribution of classes excluding new_whale');

# %%
def prepare_labels(y):
    # From here: https://www.kaggle.com/pestipeti/keras-cnn-starter
    values = np.array(y)
    label_encoder = LabelEncoder()
    integer_encoded = label_encoder.fit_transform(values)

    onehot_encoder = OneHotEncoder(sparse=False)
    integer_encoded = integer_encoded.reshape(len(integer_encoded), 1)
    onehot_encoded = onehot_encoder.fit_transform(integer_encoded)

    y = onehot_encoded
    return y, label_encoder

# %%
y, le = prepare_labels(train_df['Id'])
y_ts, le_ts = prepare_labels(test_df['Id'])
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Prepare Network

# %% [markdown]
# ### Simple CNN

# %%
class WhaleDataset(Dataset):
    def __init__(self, datafolder, datatype='train', df=None, transform = transforms.Compose([transforms.ToTensor()]), y=None):
        self.datafolder = datafolder
        self.datatype = datatype
        self.y = y
        if self.datatype == 'train':
            self.df = df.values
        self.image_files_list = [s for s in os.listdir(datafolder)]
        self.transform = transform


    def __len__(self):
        return len(self.image_files_list)
    
    def __getitem__(self, idx):
        if self.datatype == 'train':
            img_name = os.path.join(self.datafolder, self.df[idx - 1][0])
            label = self.y[idx - 1]
            
        elif self.datatype == 'test':
            img_name = os.path.join(self.datafolder, self.image_files_list[idx - 1])
            label = np.zeros((4571,))

        image = Image.open(img_name).convert('RGB')
        image = self.transform(image)
        if self.datatype == 'train':
            return image, label
        elif self.datatype == 'test':
            # so that the images will be in a correct order
            return image, label, self.image_files_list[idx]

# %%
data_transforms = transforms.Compose([
                                      transforms.Resize((100, 100)),
                                      transforms.ToTensor(),
                                      transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                             std=[0.229, 0.224, 0.225])
    ])
data_transforms_test = transforms.Compose([
                                           transforms.Resize((100, 100)),
                                           transforms.ToTensor(),
                                           transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                                 std=[0.229, 0.224, 0.225])
])

# %%
train_dataset = WhaleDataset(datafolder='./whaletrain/', datatype='train', df=train_df, transform=data_transforms, y=y)
test_set = WhaleDataset(datafolder='./whaletest/', datatype='train', df=test_df, transform=data_transforms_test,y = y_ts)

train_sampler = SubsetRandomSampler(list(range(len(train_df))))#len(os.listdir('./whaletrain')))))
valid_sampler = SubsetRandomSampler(list(range(len(train_df))))#len(os.listdir('./whaletrain')))))
batch_size = 32
num_workers = 0

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, sampler=train_sampler, num_workers=num_workers)
# less size for test loader.
test_loader = torch.utils.data.DataLoader(test_set, batch_size=32, num_workers=num_workers)

# %%
class Net(nn.Module):
    def __init__(self, num_classes):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, 7, padding=1)
        self.conv2_bn = nn.BatchNorm2d(32)
        self.pool = nn.MaxPool2d(2, 2)
        
        self.conv2 = nn.Conv2d(32, 64, 3, padding=1)        
        self.pool2 = nn.AvgPool2d(3, 3)
        
        self.fc1 = nn.Linear(64 * 4 * 4 * 16, 1024)
        self.fc2 = nn.Linear(1024, num_classes)

        self.dropout = nn.Dropout(0.5)        

    def forward(self, x):
        x = self.pool(F.relu(self.conv2_bn(self.conv1(x))))
        x = self.pool2(F.relu(self.conv2(x)))
        x = x.view(-1, 64 * 4 * 4 * 16)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.fc2(x)

        return x

# %%
model_conv = Net(4570)
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model_conv.parameters(), lr=0.01)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)

# %% [markdown]
# # Resnet 18

# %%
class WhaleDataset(Dataset):
    def __init__(self, datafolder, datatype='train', df=None, transform = transforms.Compose([transforms.ToTensor()]), y=None):
        self.datafolder = datafolder
        self.datatype = datatype
        self.y = y
        if self.datatype == 'train':
            self.df = df.values
        self.image_files_list = [s for s in os.listdir(datafolder)]
        self.transform = transform


    def __len__(self):
        return len(self.image_files_list)
    
    def __getitem__(self, idx):
        if self.datatype == 'train':
            img_name = os.path.join(self.datafolder, self.df[idx - 1][0])
            label = self.y[idx - 1]
            
        elif self.datatype == 'test':
            img_name = os.path.join(self.datafolder, self.image_files_list[idx - 1])
            label = np.zeros((4571,))

        image = Image.open(img_name).convert('RGB')
        image = self.transform(image)
        if self.datatype == 'train':
            return image, label
        elif self.datatype == 'test':
            # so that the images will be in a correct order
            return image, label, self.image_files_list[idx]

# %%
data_transforms = transforms.Compose([
                                      transforms.RandomResizedCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                             std=[0.229, 0.224, 0.225])
    ])
data_transforms_test = transforms.Compose([
                                           transforms.RandomResizedCrop(224),
                                           transforms.ToTensor(),
                                           transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                                 std=[0.229, 0.224, 0.225])
])

# %%
train_dataset = WhaleDataset(datafolder='./whaletrain/', datatype='train', df=train_df, transform=data_transforms, y=y)
test_set = WhaleDataset(datafolder='./whaletest/', datatype='train', df=test_df, transform=data_transforms_test,y = y_ts)
#test
train_sampler = SubsetRandomSampler(list(range(len(train_df))))#len(os.listdir('./whaletrain')))))
valid_sampler = SubsetRandomSampler(list(range(len(train_df))))#len(os.listdir('./whaletrain')))))
batch_size = 10
num_workers = 0

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, sampler=train_sampler, num_workers=num_workers)
# less size for test loader.
test_loader = torch.utils.data.DataLoader(test_set, batch_size=32, num_workers=num_workers)

# %%
class ResidualBlock(nn.Module):
    def __init__(self, inchannel, outchannel, stride=1):
        super(ResidualBlock, self).__init__()
        self.left = nn.Sequential(
            nn.Conv2d(inchannel, outchannel, kernel_size=3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(outchannel),
            nn.ReLU(inplace=True),
            nn.Conv2d(outchannel, outchannel, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(outchannel)
        )
        self.shortcut = nn.Sequential()
        if stride != 1 or inchannel != outchannel:
            self.shortcut = nn.Sequential(
                nn.Conv2d(inchannel, outchannel, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(outchannel)
            )

    def forward(self, x):
        out = self.left(x)
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class ResNet(nn.Module):
    def __init__(self, ResidualBlock, num_classes=4571):
        super(ResNet, self).__init__()
        self.inchannel = 64
        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(),
        )
        self.layer1 = self.make_layer(ResidualBlock, 64,  2, stride=1)
        self.layer2 = self.make_layer(ResidualBlock, 128, 2, stride=2)
        self.layer3 = self.make_layer(ResidualBlock, 256, 2, stride=2)
        self.layer4 = self.make_layer(ResidualBlock, 512, 2, stride=2)
        self.fc = nn.Linear(512, num_classes)

    def make_layer(self, block, channels, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)   #strides=[1,1]
        layers = []
        for stride in strides:
            layers.append(block(self.inchannel, channels, stride))
            self.inchannel = channels
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.conv1(x)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        return out

# %%
model_conv = ResNet(ResidualBlock)
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model_conv.parameters(), lr=0.01)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)

# %%
num_classes = 4571
model_conv = models.resnet18(pretrained=True)
num_ftrs = model_conv.fc.in_features #最后fc层的输入
model_conv.fc = nn.Linear(num_ftrs, num_classes) #NUM_CLASSES是自己数据的类别
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model_conv.parameters(), lr=0.01)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)
model_conv.load_state_dict(torch.load('./model/Res18.pth'))

# %%
model_conv.cuda()
total = list(0. for i in range(test_df.Id.nunique()))
correct = list(0. for i in range(test_df.Id.nunique()))
# llloss = [0] * (n_epochs + 1)

accuracy = []
    
# train
for batch_i, (data, target) in enumerate(test_loader):
    data, target = data.cuda(), target.cuda()

    optimizer.zero_grad()
    output = model_conv(data)
    predicted = torch.argmax(output, 1)

    res = (predicted == torch.argmax(target, 1)).squeeze()

    for label_idx in range(len(target)):

        label_single = torch.argmax(target, 1)[label_idx]
        correct[label_single] += res[label_idx].item()
        total[label_single] += 1

acc = sum(correct)/sum(total)
print(f'acc : {acc}')
# Out:
# acc : 0.4764439187857284

# %% [markdown]
# # Train

# %% [markdown]
# ### Every model use the same one

# %%
model_conv.cuda()
n_epochs = 10 #10
acc = [0] * (n_epochs + 1)
total = list(0. for i in range(train_df.Id.nunique()))
correct = list(0. for i in range(train_df.Id.nunique()))
llloss = [0] * (n_epochs + 1)

for epoch in range(1, n_epochs+1):
    print(time.ctime(), 'Epoch:', epoch)

    train_loss = []
    valid_loss = []
    exp_lr_scheduler.step()
    accuracy = []
    
    # train
    for batch_i, (data, target) in enumerate(train_loader):
        #print(batch_i)
        data, target = data.cuda(), target.cuda()

        optimizer.zero_grad()
        output = model_conv(data)
        predicted = torch.argmax(output, 1)

        res = (predicted == torch.argmax(target, 1)).squeeze()
        
        for label_idx in range(len(target)):
            
            label_single = torch.argmax(target, 1)[label_idx]
            correct[label_single] += res[label_idx].item()
            total[label_single] += 1

        
        loss = criterion(output, target.float())
        train_loss.append(loss.item())
        loss.backward()
        optimizer.step()
        
        
    llloss[epoch] = np.mean(train_loss)
    acc[epoch] = sum(correct)/sum(total)
    print(f'Epoch {epoch}, train loss: {llloss[epoch]}, acc : {acc[epoch]}')
    
acc_base_train = acc
loss_base_train = llloss
# Out:
# Mon Jun  3 17:55:23 2019 Epoch: 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-cee13cd481ab> in <module>()
#      15
#      16     # train
# ---> 17     for batch_i, (data, target) in enumerate(train_loader):
#      18         #print(batch_i)
#      19         data, target = data.cuda(), target.cuda()
#
# /opt/conda/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# /opt/conda/lib/python3.6/site-packages/torch/utils/data/dataloader.py in <listcomp>(.0)
#     613         if self.num_workers == 0:  # same-process loading
#     614             indices = next(self.sample_iter)  # may raise StopIteration
# --> 615             batch = self.collate_fn([self.dataset[i] for i in indices])
#     616             if self.pin_memory:
#     617                 batch = pin_memory_batch(batch)
#
# <ipython-input-40-177575f61c98> in __getitem__(self, idx)
#      22             label = np.zeros((4571,))
#      23
# ---> 24         image = Image.open(img_name).convert('RGB')
#      25         image = self.transform(image)
#      26         if self.datatype == 'train':
#
# /opt/conda/lib/python3.6/site-packages/PIL/Image.py in convert(self, mode, matrix, dither, palette, colors)
#     913         """
#     914
# --> 915         self.load()
#     916
#     917         if not mode and self.mode == "P":
#
# /opt/conda/lib/python3.6/site-packages/PIL/ImageFile.py in load(self)
#     239
#     240                             b = b + s
# --> 241                             n, err_code = decoder.decode(b)
#     242                             if n < 0:
#     243                                 break
#
# KeyboardInterrupt:

# %%
torch.save(model_conv.state_dict(), './model/simplecnn_1epoch.pkl')
#model_object.load_state_dict(torch.load('params.pkl'))

# %%
torch.save(model_conv.state_dict(), './model/resnet18.pkl')

# %%
model_conv.load_state_dict(torch.load('./model/simplecnn.pkl'))

# %%
result = []
model_conv.cuda()
for batch_i, (data, target) in enumerate(train_loader):
    #print(batch_i)
    data, target = data.cuda(), target.cuda()
    optimizer.zero_grad()
    output = model_conv(data)
    predicted = torch.argmax(output, 1)
    res = (predicted == torch.argmax(target, 1)).squeeze()
#     for i in range(len(predicted)):
#         result.append(predicted[i])

# %%
k = 0
for i in range(len(test_df.values)):
    if test_df.values[i][1] == 'new_whale':
        k+=1

# %%
k/len(test_df)
# Out:
# 0.4764439187857284

# %% [markdown]
# ## Feature Extraction

# %%
def myimshow(image, ax=plt):
    try:
        image = image.to('cpu').detach().numpy()
    except:
        image = image
    #image = np.moveaxis(image, [0, 1, 2], [2, 0, 1]) 
    image = (image + 1) / 2
    image[image < 0] = 0
    image[image > 1] = 1 
    h = ax.imshow(image) 
    ax.axis('off') 
    return h

# %% [markdown]
# ### Train_set feature extraction

# %%
class Net_ext(nn.Module):
    def __init__(self, num_classes):
        super(Net_ext, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, 7, padding=1)
        self.conv2_bn = nn.BatchNorm2d(32)
        self.pool = nn.MaxPool2d(2, 2)
        
        self.conv2 = nn.Conv2d(32, 64, 3, padding=1)        
        self.pool2 = nn.AvgPool2d(3, 3)
        
        self.fc1 = nn.Linear(64 * 4 * 4 * 16, 1024)
        self.fc2 = nn.Linear(1024, num_classes)

        self.dropout = nn.Dropout(0.5)        

    def forward(self, x):
        x = self.pool(F.relu(self.conv2_bn(self.conv1(x))))
        x = self.pool2(F.relu(self.conv2(x)))
#         x = x.view(-1, 64 * 4 * 4 * 16)
#         x = F.relu(self.fc1(x))
#         x = self.dropout(x)
#         x = self.fc2(x)

        return x

# %%
model_conv_ext = Net_ext(4571)
# criterion = nn.BCEWithLogitsLoss()
# optimizer = optim.Adam(model_conv_ext.parameters(), lr=0.01)
# exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)

# %%
model_conv_ext.load_state_dict(torch.load('./model/simplecnn.pkl'))
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# <ipython-input-23-083963700548> in <module>()
# ----> 1 model_conv_ext.load_state_dict(torch.load('./model/simplecnn.pkl'))
#
# /opt/conda/lib/python3.6/site-packages/torch/serialization.py in load(f, map_location, pickle_module)
#     366         f = open(f, 'rb')
#     367     try:
# --> 368         return _load(f, map_location, pickle_module)
#     369     finally:
#     370         if new_fd:
#
# /opt/conda/lib/python3.6/site-packages/torch/serialization.py in _load(f, map_location, pickle_module)
#     530             f.seek(0)
#     531
# --> 532     magic_number = pickle_module.load(f)
#     533     if magic_number != MAGIC_NUMBER:
#     534         raise RuntimeError("Invalid magic number; corrupt file?")
#
# UnpicklingError: invalid load key, '\x0a'.

# %%
ext_1 = []
ext_2 = []
#for (data, target, name) in train_loader:
for batch_i, (data, target) in enumerate(train_loader):
    print(f'exctrating data in batch{batch_i}')
    data = data.cuda()
    model_conv_ext.cuda()
    output = model_conv_ext(data)
    for i in range(len(output)):
        ext_1.append((output[i].cpu().detach().numpy(),target[i]))
        ext_2.append((data[i].cpu().detach().numpy(),target[i]))
#     output = output.cpu().detach().numpy()
#     #print(batch_i)
#     data = data[0].cuda()
#     x = myexactor(data)
# Out:
# exctrating data in batch0
# exctrating data in batch1
# exctrating data in batch2
# exctrating data in batch3
# exctrating data in batch4
# exctrating data in batch5
# exctrating data in batch6
# exctrating data in batch7
# exctrating data in batch8
# exctrating data in batch9
# exctrating data in batch10
# exctrating data in batch11
# exctrating data in batch12
# exctrating data in batch13
# exctrating data in batch14
# exctrating data in batch15
# exctrating data in batch16
# exctrating data in batch17
# exctrating data in batch18
# exctrating data in batch19
# exctrating data in batch20
# exctrating data in batch21
# exctrating data in batch22
# exctrating data in batch23
# exctrating data in batch24
# exctrating data in batch25
# exctrating data in batch26
# exctrating data in batch27
# exctrating data in batch28
# exctrating data in batch29
# exctrating data in batch30
# exctrating data in batch31
# exctrating data in batch32
# exctrating data in batch33
# exctrating data in batch34
# exctrating data in batch35
# exctrating data in batch36
# exctrating data in batch37
# exctrating data in batch38
# exctrating data in batch39
# exctrating data in batch40
# exctrating data in batch41
# exctrating data in batch42
# exctrating data in batch43
# exctrating data in batch44
# exctrating data in batch45
# exctrating data in batch46
# exctrating data in batch47
# exctrating data in batch48
# exctrating data in batch49
# exctrating data in batch50
# exctrating data in batch51
# exctrating data in batch52
# exctrating data in batch53
# exctrating data in batch54
# exctrating data in batch55
# exctrating data in batch56
# exctrating data in batch57
# exctrating data in batch58
# exctrating data in batch59
# exctrating data in batch60
# exctrating data in batch61
# exctrating data in batch62
# exctrating data in batch63
# exctrating data in batch64
# exctrating data in batch65
# exctrating data in batch66
# exctrating data in batch67
# exctrating data in batch68
# exctrating data in batch69
# exctrating data in batch70
# exctrating data in batch71
# exctrating data in batch72
# exctrating data in batch73
# exctrating data in batch74
# exctrating data in batch75
# exctrating data in batch76
# exctrating data in batch77
# exctrating data in batch78
# exctrating data in batch79
# exctrating data in batch80
# exctrating data in batch81
# exctrating data in batch82
# exctrating data in batch83
# exctrating data in batch84
# exctrating data in batch85
# exctrating data in batch86
# exctrating data in batch87
# exctrating data in batch88
# exctrating data in batch89
# exctrating data in batch90
# exctrating data in batch91
# exctrating data in batch92
# exctrating data in batch93
# exctrating data in batch94
# exctrating data in batch95
# exctrating data in batch96
# exctrating data in batch97
# exctrating data in batch98
# exctrating data in batch99
# exctrating data in batch100
# exctrating data in batch101
# exctrating data in batch102
# exctrating data in batch103
# exctrating data in batch104
# exctrating data in batch105
# exctrating data in batch106
# exctrating data in batch107
# exctrating data in batch108
# exctrating data in batch109
# exctrating data in batch110
# exctrating data in batch111
# exctrating data in batch112
# exctrating data in batch113
# exctrating data in batch114
# exctrating data in batch115
# exctrating data in batch116
# exctrating data in batch117
# exctrating data in batch118
# exctrating data in batch119
# exctrating data in batch120
# exctrating data in batch121
# exctrating data in batch122
# exctrating data in batch123
# exctrating data in batch124
# exctrating data in batch125
# exctrating data in batch126
# exctrating data in batch127
# exctrating data in batch128
# exctrating data in batch129
# exctrating data in batch130
# exctrating data in batch131
# exctrating data in batch132
# exctrating data in batch133
# exctrating data in batch134
# exctrating data in batch135
# exctrating data in batch136
# exctrating data in batch137
# exctrating data in batch138
# exctrating data in batch139
# exctrating data in batch140
# exctrating data in batch141
# exctrating data in batch142
# exctrating data in batch143
# exctrating data in batch144
# exctrating data in batch145
# exctrating data in batch146
# exctrating data in batch147
# exctrating data in batch148
# exctrating data in batch149
# exctrating data in batch150
# exctrating data in batch151
# exctrating data in batch152
# exctrating data in batch153
# exctrating data in batch154
# exctrating data in batch155
# exctrating data in batch156
# exctrating data in batch157
# exctrating data in batch158
# exctrating data in batch159
# exctrating data in batch160
# exctrating data in batch161
# exctrating data in batch162
# exctrating data in batch163
# exctrating data in batch164
# exctrating data in batch165
# exctrating data in batch166
# exctrating data in batch167
# exctrating data in batch168
# exctrating data in batch169
# exctrating data in batch170
# exctrating data in batch171
# exctrating data in batch172
# exctrating data in batch173
# exctrating data in batch174
# exctrating data in batch175
# exctrating data in batch176
# exctrating data in batch177
# exctrating data in batch178
# exctrating data in batch179
# exctrating data in batch180
# exctrating data in batch181
# exctrating data in batch182
# exctrating data in batch183
# exctrating data in batch184
# exctrating data in batch185
# exctrating data in batch186
# exctrating data in batch187
# exctrating data in batch188
# exctrating data in batch189
# exctrating data in batch190
# exctrating data in batch191
# exctrating data in batch192
# exctrating data in batch193
# exctrating data in batch194
# exctrating data in batch195
# exctrating data in batch196
# exctrating data in batch197
# exctrating data in batch198
# exctrating data in batch199
# exctrating data in batch200
# exctrating data in batch201
# exctrating data in batch202
# exctrating data in batch203
# exctrating data in batch204
# exctrating data in batch205
# exctrating data in batch206
# exctrating data in batch207
# exctrating data in batch208
# exctrating data in batch209
# exctrating data in batch210
# exctrating data in batch211
# exctrating data in batch212
# exctrating data in batch213
# exctrating data in batch214
# exctrating data in batch215
# exctrating data in batch216
# exctrating data in batch217
# exctrating data in batch218
# exctrating data in batch219
# exctrating data in batch220
# exctrating data in batch221
# exctrating data in batch222
# exctrating data in batch223
# exctrating data in batch224
# exctrating data in batch225
# exctrating data in batch226
# exctrating data in batch227
# exctrating data in batch228
# exctrating data in batch229
# exctrating data in batch230
# exctrating data in batch231
# exctrating data in batch232
# exctrating data in batch233
# exctrating data in batch234
# exctrating data in batch235
# exctrating data in batch236
# exctrating data in batch237
# exctrating data in batch238
# exctrating data in batch239
# exctrating data in batch240
# exctrating data in batch241
# exctrating data in batch242
# exctrating data in batch243
# exctrating data in batch244
# exctrating data in batch245
# exctrating data in batch246
# exctrating data in batch247
# exctrating data in batch248
# exctrating data in batch249
# exctrating data in batch250
# exctrating data in batch251
# exctrating data in batch252
# exctrating data in batch253
# exctrating data in batch254
# exctrating data in batch255
# exctrating data in batch256
# exctrating data in batch257
# exctrating data in batch258
# exctrating data in batch259
# exctrating data in batch260
# exctrating data in batch261
# exctrating data in batch262
# exctrating data in batch263
# exctrating data in batch264
# exctrating data in batch265
# exctrating data in batch266
# exctrating data in batch267
# exctrating data in batch268
# exctrating data in batch269
# exctrating data in batch270
# exctrating data in batch271
# exctrating data in batch272
# exctrating data in batch273
# exctrating data in batch274
# exctrating data in batch275
# exctrating data in batch276
# exctrating data in batch277
# exctrating data in batch278
# exctrating data in batch279
# exctrating data in batch280
# exctrating data in batch281
# exctrating data in batch282
# exctrating data in batch283
# exctrating data in batch284
# exctrating data in batch285
# exctrating data in batch286
# exctrating data in batch287
# exctrating data in batch288
# exctrating data in batch289
# exctrating data in batch290
# exctrating data in batch291
# exctrating data in batch292
# exctrating data in batch293
# exctrating data in batch294
# exctrating data in batch295
# exctrating data in batch296
# exctrating data in batch297
# exctrating data in batch298
# exctrating data in batch299
# exctrating data in batch300
# exctrating data in batch301
# exctrating data in batch302
# exctrating data in batch303
# exctrating data in batch304
# exctrating data in batch305
# exctrating data in batch306
# exctrating data in batch307
# exctrating data in batch308
# exctrating data in batch309
# exctrating data in batch310
# exctrating data in batch311
# exctrating data in batch312
# exctrating data in batch313
# exctrating data in batch314
# exctrating data in batch315
# exctrating data in batch316
# exctrating data in batch317
# exctrating data in batch318
# exctrating data in batch319
# exctrating data in batch320
# exctrating data in batch321
# exctrating data in batch322
# exctrating data in batch323
# exctrating data in batch324
# exctrating data in batch325
# exctrating data in batch326
# exctrating data in batch327
# exctrating data in batch328
# exctrating data in batch329
# exctrating data in batch330
# exctrating data in batch331
# exctrating data in batch332
# exctrating data in batch333
# exctrating data in batch334
# exctrating data in batch335
# exctrating data in batch336
# exctrating data in batch337
# exctrating data in batch338
# exctrating data in batch339
# exctrating data in batch340
# exctrating data in batch341
# exctrating data in batch342
# exctrating data in batch343
# exctrating data in batch344
# exctrating data in batch345
# exctrating data in batch346
# exctrating data in batch347
# exctrating data in batch348
# exctrating data in batch349
# exctrating data in batch350
# exctrating data in batch351
# exctrating data in batch352
# exctrating data in batch353
# exctrating data in batch354
# exctrating data in batch355
# exctrating data in batch356
# exctrating data in batch357
# exctrating data in batch358
# exctrating data in batch359
# exctrating data in batch360
# exctrating data in batch361
# exctrating data in batch362
# exctrating data in batch363
# exctrating data in batch364
# exctrating data in batch365
# exctrating data in batch366
# exctrating data in batch367
# exctrating data in batch368
# exctrating data in batch369
# exctrating data in batch370
# exctrating data in batch371
# exctrating data in batch372
# exctrating data in batch373
# exctrating data in batch374
# exctrating data in batch375
# exctrating data in batch376
# exctrating data in batch377
# exctrating data in batch378
# exctrating data in batch379
# exctrating data in batch380
# exctrating data in batch381
# exctrating data in batch382
# exctrating data in batch383
# exctrating data in batch384
# exctrating data in batch385
# exctrating data in batch386
# exctrating data in batch387
# exctrating data in batch388
# exctrating data in batch389
# exctrating data in batch390
# exctrating data in batch391
# exctrating data in batch392
# exctrating data in batch393
# exctrating data in batch394
# exctrating data in batch395
# exctrating data in batch396
# exctrating data in batch397
# exctrating data in batch398
# exctrating data in batch399
# exctrating data in batch400
# exctrating data in batch401
# exctrating data in batch402
# exctrating data in batch403
# exctrating data in batch404
# exctrating data in batch405
# exctrating data in batch406
# exctrating data in batch407
# exctrating data in batch408
# exctrating data in batch409
# exctrating data in batch410
# exctrating data in batch411
# exctrating data in batch412
# exctrating data in batch413
# exctrating data in batch414
# exctrating data in batch415
# exctrating data in batch416
# exctrating data in batch417
# exctrating data in batch418
# exctrating data in batch419
# exctrating data in batch420
# exctrating data in batch421
# exctrating data in batch422
# exctrating data in batch423
# exctrating data in batch424
# exctrating data in batch425
# exctrating data in batch426
# exctrating data in batch427
# exctrating data in batch428
# exctrating data in batch429
# exctrating data in batch430
# exctrating data in batch431
# exctrating data in batch432
# exctrating data in batch433
# exctrating data in batch434
# exctrating data in batch435
# exctrating data in batch436
# exctrating data in batch437
# exctrating data in batch438
# exctrating data in batch439
# exctrating data in batch440
# exctrating data in batch441
# exctrating data in batch442
# exctrating data in batch443
# exctrating data in batch444
# exctrating data in batch445
# exctrating data in batch446
# exctrating data in batch447
# exctrating data in batch448
# exctrating data in batch449
# exctrating data in batch450
# exctrating data in batch451
# exctrating data in batch452
# exctrating data in batch453
# exctrating data in batch454
# exctrating data in batch455
# exctrating data in batch456
# exctrating data in batch457
# exctrating data in batch458
# exctrating data in batch459
# exctrating data in batch460
# exctrating data in batch461
# exctrating data in batch462
# exctrating data in batch463
# exctrating data in batch464
# exctrating data in batch465
# exctrating data in batch466
# exctrating data in batch467
# exctrating data in batch468
# exctrating data in batch469
# exctrating data in batch470
# exctrating data in batch471
# exctrating data in batch472
# exctrating data in batch473
# exctrating data in batch474
# exctrating data in batch475
# exctrating data in batch476
# exctrating data in batch477
# exctrating data in batch478
# exctrating data in batch479
# exctrating data in batch480
# exctrating data in batch481
# exctrating data in batch482
# exctrating data in batch483
# exctrating data in batch484
# exctrating data in batch485
# exctrating data in batch486
# exctrating data in batch487
# exctrating data in batch488
# exctrating data in batch489
# exctrating data in batch490
# exctrating data in batch491
# exctrating data in batch492
# exctrating data in batch493
# exctrating data in batch494
# exctrating data in batch495
# exctrating data in batch496
# exctrating data in batch497
# exctrating data in batch498
# exctrating data in batch499
# exctrating data in batch500
# exctrating data in batch501
# exctrating data in batch502
# exctrating data in batch503
# exctrating data in batch504
# exctrating data in batch505
# exctrating data in batch506
# exctrating data in batch507
# exctrating data in batch508
# exctrating data in batch509
# exctrating data in batch510
# exctrating data in batch511
# exctrating data in batch512
# exctrating data in batch513
# exctrating data in batch514
# exctrating data in batch515
# exctrating data in batch516
# exctrating data in batch517
# exctrating data in batch518
# exctrating data in batch519
# exctrating data in batch520
# exctrating data in batch521
# exctrating data in batch522
# exctrating data in batch523
# exctrating data in batch524
# exctrating data in batch525
# exctrating data in batch526
# exctrating data in batch527
# exctrating data in batch528
# exctrating data in batch529
# exctrating data in batch530
# exctrating data in batch531
# exctrating data in batch532
# exctrating data in batch533
# exctrating data in batch534
# exctrating data in batch535
# exctrating data in batch536
# exctrating data in batch537
# exctrating data in batch538
# exctrating data in batch539
# exctrating data in batch540
# exctrating data in batch541
# exctrating data in batch542
# exctrating data in batch543
# exctrating data in batch544
# exctrating data in batch545
# exctrating data in batch546
# exctrating data in batch547
# exctrating data in batch548
# exctrating data in batch549
# exctrating data in batch550
# exctrating data in batch551
# exctrating data in batch552
# exctrating data in batch553
# exctrating data in batch554
# exctrating data in batch555
# exctrating data in batch556
# exctrating data in batch557
# exctrating data in batch558
# exctrating data in batch559
# exctrating data in batch560
# exctrating data in batch561
# exctrating data in batch562
# exctrating data in batch563
# exctrating data in batch564
# exctrating data in batch565
# exctrating data in batch566
# exctrating data in batch567
# exctrating data in batch568
# exctrating data in batch569
# exctrating data in batch570
# exctrating data in batch571
# exctrating data in batch572
# exctrating data in batch573
# exctrating data in batch574
# exctrating data in batch575
# exctrating data in batch576
# exctrating data in batch577
# exctrating data in batch578
# exctrating data in batch579
# exctrating data in batch580
# exctrating data in batch581
# exctrating data in batch582
# exctrating data in batch583
# exctrating data in batch584
# exctrating data in batch585
# exctrating data in batch586
# exctrating data in batch587
# exctrating data in batch588
# exctrating data in batch589
# exctrating data in batch590
# exctrating data in batch591
# exctrating data in batch592
# exctrating data in batch593
# exctrating data in batch594
# exctrating data in batch595
# exctrating data in batch596
# exctrating data in batch597
# exctrating data in batch598
# exctrating data in batch599
# exctrating data in batch600
# exctrating data in batch601
# exctrating data in batch602
# exctrating data in batch603
# exctrating data in batch604
# exctrating data in batch605
# exctrating data in batch606
# exctrating data in batch607
# exctrating data in batch608
# exctrating data in batch609
# exctrating data in batch610
# exctrating data in batch611
# exctrating data in batch612
# exctrating data in batch613
# exctrating data in batch614
# exctrating data in batch615
# exctrating data in batch616
# exctrating data in batch617
# exctrating data in batch618
# exctrating data in batch619
# exctrating data in batch620
# exctrating data in batch621
# exctrating data in batch622
# exctrating data in batch623
# exctrating data in batch624
# exctrating data in batch625
# exctrating data in batch626
# exctrating data in batch627
# exctrating data in batch628
# exctrating data in batch629
# exctrating data in batch630
# exctrating data in batch631
# exctrating data in batch632
# exctrating data in batch633

# %%
len(train_loader)
# Out:
# 634

# %%
model_conv_ext.state_dict()
# Out:
# OrderedDict([('conv1.weight',
#               tensor([[[[ 9.1796e-02,  5.5529e-02,  7.5668e-02,  ..., -5.6558e-02,
#                           5.5959e-02, -2.2185e-02],
#                         [ 7.9609e-02,  9.3126e-02,  1.5645e-01,  ...,  9.4937e-02,
#                           5.4867e-02,  6.9046e-02],
#                         [ 1.0498e-01,  3.3667e-02,  9.1928e-02,  ...,  5.1464e-03,
#                          -1.5053e-02, -2.1319e-02],
#                         ...,
#                         [ 1.1581e-01,  1.0193e-01,  1.5696e-01,  ...,  1.1076e-01,
#                           1.5026e-01, -6.6370e-02],
#                         [ 3.5093e-02, -1.6031e-03,  8.8651e-02,  ...,  1.4071e-01,
#                          -1.4636e-03, -7.9728e-02],
#                         [-6.4359e-02,  2.8535e-02,  1.1978e-02,  ..., -6.1638e-02,
#                          -4.9941e-03, -1.3749e-01]],
#
#                        [[-1.1197e-02,  2.4151e-02,  4.9759e-02,  ..., -3.3791e-02,
#                          -6.4447e-02,  5.9974e-02],
#                         [ 1.4611e-01,  2.2994e-01,  2.4766e-01,  ...,  8.5725e-02,
#                          -1.4884e-02,  1.0840e-01],
#                         [ 1.3614e-01,  1.1173e-01,  3.6589e-01,  ...,  2.9756e-01,
#                           2.0235e-01, -2.2379e-02],
#                         ...,
#                         [ 1.3028e-01,  4.0529e-01,  1.2481e-01,  ...,  5.9921e-02,
#                           1.4515e-03, -2.2006e-02],
#                         [ 8.3449e-02,  2.7681e-01,  1.9789e-01,  ...,  6.5823e-02,
#                           5.0936e-02, -6.9828e-02],
#                         [-2.6107e-02,  1.6721e-01,  4.5896e-02,  ..., -5.0047e-02,
#                           4.1025e-03, -7.6814e-02]],
#
#                        [[ 3.2039e-02,  5.0248e-02, -4.7460e-03,  ..., -3.9546e-02,
#                           5.6332e-02,  5.6873e-02],
#                         [ 2.7849e-01,  2.5141e-01,  2.7784e-01,  ...,  2.1849e-01,
#                           1.4871e-01,  7.2202e-02],
#                         [ 3.6486e-01,  3.0520e-01,  5.8092e-01,  ...,  3.8076e-01,
#                           3.8881e-01,  1.8304e-01],
#                         ...,
#                         [ 2.3562e-01,  3.4886e-01,  3.5026e-01,  ...,  1.9085e-01,
#                           1.8043e-01,  1.8997e-01],
#                         [ 2.1116e-01,  3.2359e-01,  3.8092e-01,  ...,  7.1313e-02,
#                           1.9182e-01,  2.1251e-01],
#                         [ 5.8697e-02,  1.1281e-01,  1.6364e-01,  ...,  1.5617e-01,
#                           6.0851e-02,  1.8427e-02]]],
#
#
#                       [[[-8.3702e-02, -1.8780e-02, -5.2226e-02,  ..., -1.0797e-01,
#                          -5.7745e-02, -3.3807e-02],
#                         [-9.8124e-02, -6.0147e-02, -7.7994e-02,  ..., -8.3058e-02,
#                          -1.2766e-01, -1.9626e-01],
#                         [-6.2407e-02, -7.7142e-02, -3.8855e-02,  ..., -9.2908e-02,
#                          -1.6957e-01, -1.4797e-01],
#                         ...,
#                         [-1.9501e-01, -1.5357e-01, -2.1495e-01,  ..., -1.5211e-01,
#                          -1.6744e-01, -1.9612e-01],
#                         [-2.0899e-01, -2.0475e-01, -2.1909e-01,  ..., -1.0115e-01,
#                          -1.5208e-01, -2.3033e-01],
#                         [-1.2700e-01, -2.2196e-01, -1.2554e-01,  ..., -1.2035e-01,
#                          -1.5626e-01, -1.3881e-01]],
#
#                        [[ 1.3449e-02, -1.0489e-01, -1.0050e-01,  ..., -1.6569e-01,
#                           4.9411e-02,  9.9523e-02],
#                         [-1.6116e-02, -6.1358e-02, -5.2213e-02,  ..., -1.7946e-01,
#                           4.8721e-02,  7.9109e-02],
#                         [-1.0482e-01, -1.6908e-01, -2.6649e-01,  ..., -2.1396e-01,
#                           1.4298e-03, -1.0124e-01],
#                         ...,
#                         [-1.8399e-01, -2.5622e-01, -1.9820e-01,  ..., -2.2912e-01,
#                          -1.5608e-01, -1.1091e-01],
#                         [-2.6778e-01, -2.5454e-01, -2.0532e-01,  ..., -1.3320e-01,
#                          -5.7998e-02, -1.6103e-01],
#                         [-1.1743e-01, -1.6664e-01, -1.8810e-01,  ..., -1.3943e-01,
#                          -1.4486e-01, -5.6811e-02]],
#
#                        [[-4.5266e-02, -1.0689e-02, -3.6954e-02,  ...,  7.3424e-02,
#                          -2.5710e-02,  7.5682e-02],
#                         [ 2.7926e-03,  1.9565e-02,  6.9508e-02,  ...,  2.1011e-03,
#                           5.7261e-02, -2.5949e-02],
#                         [-1.8404e-02,  5.6310e-02,  1.5602e-02,  ...,  1.5585e-02,
#                           7.1333e-02,  4.5392e-02],
#                         ...,
#                         [ 1.2197e-02,  2.6163e-02, -3.6849e-02,  ..., -5.6228e-02,
#                           5.7570e-02,  2.7578e-02],
#                         [-3.2369e-02, -6.2461e-02, -1.6114e-02,  ...,  2.9184e-02,
#                           6.9279e-02,  5.9420e-02],
#                         [-3.9461e-02, -5.9358e-02, -4.2322e-03,  ..., -9.2905e-02,
#                           7.5195e-03, -7.5116e-02]]],
#
#
#                       [[[-4.4236e-02, -4.1549e-02, -3.4024e-02,  ...,  2.5256e-02,
#                          -4.5011e-02, -2.7512e-02],
#                         [-6.6999e-02, -1.6466e-03,  3.9283e-02,  ..., -1.9254e-02,
#                          -1.2425e-01, -7.8472e-02],
#                         [ 5.5763e-02,  1.0634e-02, -3.9769e-02,  ..., -5.4633e-02,
#                          -2.8294e-02, -1.6948e-01],
#                         ...,
#                         [-5.7817e-02, -1.5607e-01, -1.8441e-01,  ..., -2.5519e-01,
#                          -1.8062e-01, -2.8734e-01],
#                         [-1.2117e-01, -1.1299e-01, -7.9544e-02,  ..., -1.1155e-01,
#                          -2.1498e-01, -2.6655e-01],
#                         [-4.3589e-02, -1.4696e-01, -2.1691e-01,  ..., -1.2769e-01,
#                          -1.3867e-01, -1.1142e-01]],
#
#                        [[-3.4055e-02,  7.0778e-02,  7.5423e-03,  ...,  5.7740e-03,
#                           6.9151e-02,  1.2846e-04],
#                         [-4.3246e-02,  6.3857e-02, -1.6301e-02,  ...,  5.2228e-02,
#                          -3.9486e-02,  6.8692e-02],
#                         [ 7.5527e-03, -1.1705e-01, -1.0926e-01,  ..., -5.3514e-02,
#                          -8.2765e-02,  6.8860e-03],
#                         ...,
#                         [-1.0301e-01, -1.3339e-01, -3.3400e-01,  ..., -1.8836e-01,
#                          -5.0883e-02, -1.2010e-01],
#                         [-1.6810e-01, -1.8255e-01, -2.5693e-01,  ..., -1.7821e-01,
#                          -1.3646e-01, -1.1036e-01],
#                         [-1.7438e-01, -1.7205e-01, -2.9698e-01,  ..., -2.1138e-01,
#                          -1.7834e-01, -2.0570e-01]],
#
#                        [[ 6.6501e-02,  4.0125e-02, -1.6766e-02,  ...,  1.0410e-01,
#                          -2.9271e-02,  1.2497e-02],
#                         [-5.1199e-02,  7.2655e-02,  8.3715e-02,  ...,  1.1764e-02,
#                          -3.1068e-02, -2.8095e-02],
#                         [-7.0315e-02, -7.6697e-04,  3.8604e-02,  ..., -6.9017e-02,
#                          -5.7893e-02, -4.1843e-02],
#                         ...,
#                         [-7.4734e-02, -9.3045e-02, -1.6473e-01,  ..., -1.0307e-01,
#                           2.0633e-02,  3.6751e-02],
#                         [-2.3044e-01, -1.9245e-01, -1.5299e-01,  ..., -5.2345e-02,
#                           4.9110e-03,  1.5996e-02],
#                         [-1.1748e-01, -7.8555e-02, -1.4048e-01,  ..., -3.9551e-02,
#                          -1.5300e-01, -3.7147e-02]]],
#
#
#                       ...,
#
#
#                       [[[ 1.8851e-02, -9.0441e-02, -2.0775e-02,  ..., -8.7539e-02,
#                          -9.8978e-02, -2.2796e-01],
#                         [ 3.3382e-03, -1.0344e-01, -6.4122e-02,  ..., -1.4285e-01,
#                          -1.7001e-01, -2.7391e-01],
#                         [-2.0746e-02, -8.4414e-02, -7.7054e-02,  ..., -6.2524e-02,
#                          -5.7149e-02, -1.9507e-01],
#                         ...,
#                         [-2.1239e-02,  2.8076e-03, -4.6720e-02,  ..., -2.8913e-02,
#                          -4.3336e-02, -3.0093e-02],
#                         [-5.5961e-03, -1.2560e-02,  3.9661e-02,  ..., -7.0571e-03,
#                          -1.0028e-01, -1.1982e-01],
#                         [ 3.4648e-02,  5.6887e-02,  7.1680e-02,  ..., -3.1595e-02,
#                           2.4947e-02, -1.1704e-01]],
#
#                        [[-1.0294e-01, -4.9157e-02, -4.0444e-02,  ..., -3.1248e-01,
#                          -2.6115e-01, -2.1628e-01],
#                         [-8.9523e-02, -1.3860e-02, -8.3792e-02,  ..., -1.1411e-01,
#                          -1.5459e-01, -1.9330e-01],
#                         [ 2.8261e-02, -1.0703e-01, -6.8011e-02,  ..., -2.7369e-01,
#                          -8.0178e-02, -1.5013e-01],
#                         ...,
#                         [-9.5376e-02,  4.5602e-02, -5.7291e-02,  ..., -1.2381e-01,
#                          -1.8540e-01, -3.5254e-01],
#                         [ 2.3009e-02,  4.6856e-02,  2.0643e-02,  ..., -1.5483e-01,
#                          -1.8824e-01, -2.3985e-01],
#                         [ 4.2801e-03,  8.6147e-02,  1.0945e-01,  ..., -7.8976e-02,
#                          -2.0650e-01, -1.9287e-01]],
#
#                        [[-7.6396e-02, -3.7478e-02, -1.1011e-01,  ..., -1.2338e-01,
#                          -2.0531e-01, -2.1094e-01],
#                         [-1.6386e-01, -2.0534e-01, -2.4964e-01,  ..., -8.5293e-02,
#                          -8.3321e-02, -7.7084e-02],
#                         [-7.9135e-02, -1.4165e-01, -2.8744e-01,  ..., -9.6531e-02,
#                          -1.9556e-01, -7.6025e-02],
#                         ...,
#                         [-1.2976e-01, -1.4691e-01, -1.6621e-01,  ..., -1.5455e-01,
#                          -9.7166e-02, -2.3704e-01],
#                         [-9.8627e-02, -1.7570e-01, -9.4433e-02,  ..., -4.1482e-02,
#                          -1.7166e-01, -2.5743e-01],
#                         [-1.8496e-01, -1.1659e-01, -1.3090e-01,  ..., -1.8437e-01,
#                          -1.9993e-01, -2.0529e-01]]],
#
#
#                       [[[-5.7347e-02,  7.6529e-04, -9.3273e-02,  ..., -1.2717e-01,
#                          -1.5106e-02, -1.4289e-01],
#                         [-3.0097e-02, -2.8911e-02, -6.7232e-02,  ..., -2.7023e-02,
#                          -1.3313e-01, -1.4686e-01],
#                         [-3.5717e-02, -1.0104e-01, -9.1657e-02,  ..., -1.3285e-01,
#                          -1.5104e-01, -2.1288e-01],
#                         ...,
#                         [-1.8352e-01, -2.9132e-01, -3.0760e-01,  ..., -3.1827e-01,
#                          -3.8599e-01, -3.3955e-01],
#                         [-2.5481e-01, -1.9880e-01, -2.4438e-01,  ..., -3.4178e-01,
#                          -3.3459e-01, -3.6037e-01],
#                         [-2.6631e-01, -2.3382e-01, -3.3080e-01,  ..., -3.6424e-01,
#                          -3.2357e-01, -2.7284e-01]],
#
#                        [[ 1.9725e-01,  1.7046e-01,  9.3660e-02,  ...,  1.5584e-01,
#                           7.7915e-02,  3.6610e-02],
#                         [ 1.1974e-01,  6.0406e-02,  1.1247e-01,  ...,  4.0746e-02,
#                           6.0388e-02, -2.9870e-02],
#                         [-1.5064e-02,  3.9453e-02,  2.3448e-03,  ..., -5.7395e-02,
#                          -4.6313e-02,  3.4792e-02],
#                         ...,
#                         [-1.6874e-01, -2.4378e-02, -3.4957e-02,  ..., -1.8465e-02,
#                           6.6590e-03, -7.9224e-02],
#                         [-7.0665e-02, -1.3308e-01, -5.2175e-02,  ..., -1.1079e-01,
#                          -1.1840e-01, -8.5612e-02],
#                         [-5.8369e-02, -9.4455e-02, -7.9541e-02,  ..., -1.0983e-01,
#                          -1.1978e-01, -8.2832e-02]],
#
#                        [[ 1.0682e-01,  7.4868e-02,  9.2729e-02,  ...,  1.4691e-01,
#                           1.7226e-01,  1.2240e-01],
#                         [ 2.1641e-01,  1.9917e-01,  1.8553e-01,  ..., -7.6680e-03,
#                           2.7407e-02,  2.3625e-03],
#                         [ 8.7542e-02,  4.2415e-02,  7.3051e-02,  ...,  2.9321e-02,
#                           4.4446e-02,  9.3003e-02],
#                         ...,
#                         [ 3.2012e-02,  8.6873e-03,  3.3893e-02,  ...,  5.8049e-02,
#                           8.6813e-02, -4.9447e-02],
#                         [-8.1172e-02, -1.1409e-01, -3.9882e-02,  ..., -6.4163e-02,
#                          -5.1392e-02, -4.5301e-03],
#                         [-1.5784e-02, -8.7118e-02, -2.5436e-02,  ..., -6.6015e-02,
#                          -9.1879e-02, -4.1271e-03]]],
#
#
#                       [[[ 8.6972e-02,  3.4334e-03,  1.0696e-01,  ...,  6.3802e-02,
#                           7.1005e-02,  7.3037e-02],
#                         [ 7.3347e-02, -2.4413e-03,  1.0507e-01,  ...,  3.2626e-02,
#                          -2.5050e-02,  8.0781e-04],
#                         [ 3.3766e-02,  3.8577e-02,  9.5962e-02,  ...,  3.7552e-02,
#                          -5.1894e-02, -5.5433e-02],
#                         ...,
#                         [ 4.2420e-03, -9.2719e-04,  2.6966e-02,  ..., -9.0234e-02,
#                           4.7348e-03,  3.0493e-02],
#                         [ 1.7547e-02,  8.8279e-02,  1.1968e-02,  ..., -6.1511e-02,
#                          -5.2563e-02, -8.4138e-02],
#                         [ 5.6492e-02, -2.4511e-02,  6.2383e-02,  ...,  4.6349e-02,
#                          -4.4230e-02, -4.7430e-02]],
#
#                        [[ 5.4655e-02,  2.4033e-02,  2.5195e-02,  ..., -5.5679e-02,
#                          -6.4722e-02,  2.1097e-02],
#                         [ 9.8086e-03,  2.6699e-02,  6.8621e-02,  ..., -3.2214e-02,
#                          -1.4537e-01, -8.2839e-02],
#                         [ 1.9736e-02, -4.0791e-02, -1.0174e-01,  ..., -1.8057e-01,
#                          -1.9698e-01, -8.4678e-02],
#                         ...,
#                         [ 2.2410e-02, -8.5024e-02, -3.1569e-02,  ..., -2.0128e-01,
#                          -1.5664e-01, -2.2447e-01],
#                         [ 1.5874e-02, -6.7417e-02, -2.3174e-02,  ..., -2.3468e-01,
#                          -1.8763e-01, -2.9278e-01],
#                         [ 7.5723e-02, -2.9464e-03, -6.6828e-03,  ..., -2.1969e-01,
#                          -2.5104e-01, -1.3957e-01]],
#
#                        [[ 5.3229e-02, -1.2120e-01, -1.1832e-01,  ..., -9.7489e-02,
#                          -7.1902e-02,  3.1722e-02],
#                         [-1.0537e-01, -1.6553e-01, -7.8850e-02,  ..., -4.5913e-02,
#                          -1.1471e-01, -1.7025e-02],
#                         [-4.9741e-02, -6.3549e-02, -9.8202e-02,  ..., -6.0326e-02,
#                          -1.5160e-01, -1.6048e-01],
#                         ...,
#                         [-5.2296e-02, -7.1264e-02, -1.9009e-01,  ..., -6.6884e-02,
#                          -1.5411e-01, -1.8011e-01],
#                         [-8.1320e-02, -6.3350e-02, -1.0108e-01,  ..., -1.4990e-01,
#                          -1.8179e-01, -7.7344e-02],
#                         [-8.8885e-02, -1.4718e-01, -4.1965e-02,  ..., -3.7910e-02,
#                          -3.8093e-02, -1.7490e-01]]]], device='cuda:0')),
#              ('conv1.bias',
#               tensor([-0.0161,  0.0771, -0.0126, -0.0350, -0.0379,  0.0609,  0.0562,  0.0606,
#                        0.0053,  0.0190,  0.0213,  0.0632,  0.0683, -0.0286,  0.0428,  0.0584,
#                       -0.0461, -0.0538, -0.0138,  0.0035,  0.0642, -0.0504,  0.0280, -0.0622,
#                        0.0821,  0.0780, -0.0250, -0.0173,  0.0083, -0.0380, -0.0178,  0.0758],
#                      device='cuda:0')),
#              ('conv2_bn.weight',
#               tensor([ 0.6827,  0.0268,  0.0806,  0.0476,  0.3394,  0.5030,  0.0020,  0.8653,
#                        0.2926,  0.2579,  0.3967,  0.2376,  0.6855,  0.5393,  0.3995,  0.2576,
#                        0.0017,  0.3450,  0.3454,  0.0301,  0.4973, -0.0018,  0.4249, -0.0259,
#                        0.0255,  0.5650,  0.2963,  0.0419,  0.3305,  0.3785,  0.0594,  0.2526],
#                      device='cuda:0')),
#              ('conv2_bn.bias',
#               tensor([-0.2971, -0.1384, -0.2501, -0.2295, -0.0065, -0.0949, -0.0723, -0.3088,
#                       -0.1742, -0.1845, -0.0562, -0.0571, -0.2076, -0.2016, -0.0106, -0.0832,
#                       -0.0603,  0.0402, -0.2489, -0.0733,  0.1997, -0.0538, -0.0491, -0.0949,
#                       -0.0828, -0.1616, -0.0233, -0.1255,  0.1718, -0.0744, -0.1595, -0.3528],
#                      device='cuda:0')),
#              ('conv2_bn.running_mean',
#               tensor([ 11.3234,  -4.0547,  -5.0226,  -4.0916, -11.8256,   8.7608,   4.8597,
#                        12.4346, -10.7504,  -7.2133,  10.5404,  -5.1538, -13.2232, -12.5879,
#                        10.7528,  -7.5410,   3.1242,  -4.0904,  -5.2170,  -4.3617,  12.1313,
#                         3.1296, -10.6917,  -3.9119,   3.7745,  18.0851, -10.6511,   4.4268,
#                         6.1113,  -8.8116,  -0.4468,  -5.4516], device='cuda:0')),
#              ('conv2_bn.running_var',
#               tensor([368.0940, 206.2990, 189.3727, 138.0148, 463.9779, 185.9850, 110.3088,
#                       767.7390, 395.9245, 197.3219, 364.8731, 223.0047, 552.8712, 466.0759,
#                       293.4831, 163.4801,  17.7769,  11.9808, 127.8880,  80.2120, 516.9128,
#                        10.5546, 424.9344,  44.7056,  13.8467, 576.3267, 494.6081,  48.6767,
#                       175.8943, 249.0278, 108.8947,  73.9054], device='cuda:0')),
#              ('conv2_bn.num_batches_tracked', tensor(20311, device='cuda:0')),
#              ('conv2.weight',
#               tensor([[[[-1.3568e-01, -8.4620e-02, -6.2804e-02],
#                         [-1.7485e-01, -1.1361e-01, -1.4581e-01],
#                         [ 2.0417e-02,  5.2130e-02,  5.5336e-02]],
#
#                        [[-1.2698e-01, -1.3527e-01, -2.3297e-02],
#                         [-3.1421e-02, -8.6344e-02, -3.0924e-02],
#                         [-1.1361e-01, -3.9072e-02, -1.3522e-03]],
#
#                        [[-2.4709e-01, -2.5920e-01, -3.0134e-01],
#                         [-2.1459e-01, -2.2525e-01, -2.5056e-01],
#                         [-2.3243e-01, -2.4961e-01, -1.4933e-01]],
#
#                        ...,
#
#                        [[-3.0315e-01, -2.6185e-01, -2.8569e-01],
#                         [-2.4005e-01, -2.5732e-01, -1.9496e-01],
#                         [-1.2405e-01, -1.3794e-01, -1.6669e-01]],
#
#                        [[-1.8910e-01, -2.2544e-01, -1.5568e-01],
#                         [-2.8506e-01, -1.8479e-01, -1.8676e-01],
#                         [-2.6108e-01, -2.8149e-01, -2.5460e-01]],
#
#                        [[-2.2705e-01, -2.7787e-01, -2.7486e-01],
#                         [-2.0955e-01, -2.0506e-01, -2.0306e-01],
#                         [-2.3968e-01, -2.8283e-01, -3.1933e-01]]],
#
#
#                       [[[-3.6834e-02, -6.3951e-02, -3.9643e-02],
#                         [-6.3822e-02, -3.3686e-02, -9.1278e-02],
#                         [ 5.7016e-02,  4.2673e-02, -6.3712e-02]],
#
#                        [[ 2.0943e-02,  3.6669e-03, -6.8674e-02],
#                         [-1.5339e-02, -9.3587e-02, -1.2637e-01],
#                         [-1.2361e-01, -7.7886e-02, -8.6346e-04]],
#
#                        [[-6.3034e-02, -9.1574e-02, -9.8506e-02],
#                         [-6.7027e-02, -6.5098e-02,  8.3982e-04],
#                         [-1.0643e-01, -6.3435e-02, -4.2355e-02]],
#
#                        ...,
#
#                        [[ 6.2756e-02, -5.2618e-03, -7.1857e-02],
#                         [ 3.3919e-03, -9.5510e-02, -8.0489e-02],
#                         [-1.4862e-03, -9.7992e-03, -3.5525e-02]],
#
#                        [[ 3.6771e-02, -5.0779e-02, -4.8138e-02],
#                         [-9.3353e-02, -5.7388e-02, -4.8516e-02],
#                         [-5.5597e-02, -2.9773e-02, -7.9350e-02]],
#
#                        [[ 3.7366e-02, -9.5418e-03, -7.3787e-02],
#                         [-7.9448e-02, -6.8177e-02, -1.1122e-01],
#                         [-1.9689e-02, -4.0555e-02, -5.6217e-02]]],
#
#
#                       [[[-1.2335e-01, -3.0438e-02, -3.8980e-02],
#                         [-9.3050e-02, -5.4732e-02, -6.3944e-02],
#                         [-1.0438e-01,  2.2176e-02, -4.0819e-02]],
#
#                        [[-3.4962e-02, -3.0161e-02, -5.4883e-02],
#                         [-1.2303e-01, -8.9412e-02, -1.2783e-01],
#                         [-1.5417e-02, -1.9731e-02, -1.0954e-01]],
#
#                        [[ 9.0821e-03, -1.3587e-03, -3.9520e-02],
#                         [-1.0405e-01, -1.3334e-02, -8.1739e-02],
#                         [-7.8463e-02, -4.4897e-02, -9.0609e-02]],
#
#                        ...,
#
#                        [[ 6.2995e-03,  7.2939e-05, -1.0267e-01],
#                         [-5.0151e-02, -5.5176e-03, -2.3305e-02],
#                         [-1.0147e-01, -1.5170e-02, -5.9294e-02]],
#
#                        [[-4.6668e-02, -7.9653e-02, -2.9089e-02],
#                         [-4.7120e-02, -5.3902e-02, -7.3747e-02],
#                         [-1.0555e-01, -3.7355e-02, -8.7679e-02]],
#
#                        [[-5.1538e-02, -3.2915e-02, -2.2339e-02],
#                         [-6.1720e-02, -5.5887e-02, -2.6206e-02],
#                         [-1.1169e-01, -7.8582e-02, -7.9265e-02]]],
#
#
#                       ...,
#
#
#                       [[[-1.1903e-02, -6.2731e-02, -5.4973e-02],
#                         [-5.9372e-02, -3.1866e-02, -1.1374e-01],
#                         [-3.1819e-02, -5.7376e-02, -3.3408e-02]],
#
#                        [[-4.0520e-02, -9.1252e-03, -1.1811e-02],
#                         [-1.0624e-01, -9.1030e-02, -9.5810e-02],
#                         [-1.0019e-01, -1.1680e-01, -1.0619e-01]],
#
#                        [[-2.2694e-02, -3.0716e-02, -1.3491e-02],
#                         [-6.9820e-02, -5.7317e-02, -2.8340e-02],
#                         [-7.6647e-02, -3.2587e-02, -2.2969e-02]],
#
#                        ...,
#
#                        [[-9.0244e-02, -1.3373e-02, -3.4733e-02],
#                         [-2.4710e-02, -9.3287e-02, -4.8966e-03],
#                         [-7.0688e-02, -5.6969e-02, -8.0455e-02]],
#
#                        [[-5.4431e-02, -8.9349e-02, -9.7942e-02],
#                         [-1.4505e-02, -8.1418e-02, -5.0336e-02],
#                         [-9.6018e-03, -6.7475e-02, -9.0740e-02]],
#
#                        [[-6.4922e-02, -7.1834e-02, -1.1309e-01],
#                         [-1.1762e-01, -7.1049e-02, -2.4254e-02],
#                         [-1.5871e-02, -5.7713e-02, -4.5430e-02]]],
#
#
#                       [[[-9.6625e-02, -2.4393e-02, -6.1191e-02],
#                         [-3.4256e-02, -7.1784e-02, -8.0891e-02],
#                         [-2.6758e-03, -4.1577e-02, -1.1337e-01]],
#
#                        [[-4.8803e-02, -5.4105e-02, -5.3719e-02],
#                         [-8.4591e-02, -8.2619e-02, -7.3260e-02],
#                         [-1.6633e-02, -6.5584e-02, -1.3012e-02]],
#
#                        [[-4.0280e-02, -1.1196e-01, -6.8638e-02],
#                         [-5.1161e-02, -9.8765e-02, -3.7116e-04],
#                         [-2.7227e-02, -9.8217e-02, -1.1277e-01]],
#
#                        ...,
#
#                        [[-8.7103e-02, -1.1160e-01, -3.2117e-02],
#                         [-1.0905e-01, -1.0897e-01, -7.2289e-02],
#                         [-6.1342e-02, -4.7183e-02, -6.2741e-02]],
#
#                        [[-5.8194e-02, -7.3619e-02, -5.9196e-02],
#                         [-8.0833e-02, -4.0070e-02, -1.2519e-02],
#                         [-2.3873e-02, -3.2897e-02, -4.3532e-02]],
#
#                        [[-3.5880e-02, -8.4185e-02, -8.6057e-03],
#                         [-1.0541e-01, -9.5124e-02, -7.1316e-02],
#                         [-3.3583e-02, -6.5857e-02, -3.1465e-02]]],
#
#
#                       [[[-8.7306e-02, -8.0889e-02, -9.0815e-02],
#                         [-2.5105e-02, -9.0233e-02, -5.4349e-02],
#                         [-1.2950e-01, -6.2048e-02, -4.4369e-02]],
#
#                        [[ 2.8848e-02, -5.0351e-02, -4.2361e-02],
#                         [-7.3479e-02, -1.0071e-01, -3.7209e-02],
#                         [-4.7034e-02, -1.0710e-01, -4.6483e-02]],
#
#                        [[-5.4383e-02, -7.1123e-02, -6.6058e-02],
#                         [-4.5114e-02, -9.4418e-02, -1.7484e-02],
#                         [-8.0594e-02, -5.5003e-02, -1.0572e-01]],
#
#                        ...,
#
#                        [[-7.5069e-03, -3.4504e-02, -1.0223e-01],
#                         [ 7.4461e-03, -6.0522e-02, -2.9333e-02],
#                         [-8.6261e-02, -7.5915e-02, -7.5367e-02]],
#
#                        [[-5.7216e-02, -6.7921e-02, -8.1290e-02],
#                         [-6.0199e-02, -2.8937e-02, -8.5549e-02],
#                         [-6.4198e-02, -4.3649e-02, -4.7515e-02]],
#
#                        [[-5.3723e-02, -6.2937e-02, -5.7599e-02],
#                         [-6.4601e-02, -7.8298e-02, -1.2210e-02],
#                         [-4.4922e-02, -3.1852e-02, -5.6096e-02]]]], device='cuda:0')),
#              ('conv2.bias',
#               tensor([ 0.0881, -0.0298, -0.1313, -0.1209, -0.0812, -0.0707, -0.0823, -0.0848,
#                       -0.0895, -0.0457,  0.1537, -0.0493, -0.0147, -0.0587,  0.0976, -0.0544,
#                       -0.0914, -0.0664, -0.0573, -0.0792, -0.1171, -0.0132, -0.0218, -0.0478,
#                       -0.0334, -0.0388, -0.0322, -0.1182, -0.1311, -0.0702, -0.0700, -0.0303,
#                        0.0691, -0.0649, -0.0441, -0.1098, -0.1121, -0.1381,  0.2432, -0.1071,
#                       -0.0526,  0.0276, -0.0632, -0.1214, -0.0870, -0.3208, -0.0610, -0.0563,
#                       -0.1150, -0.0493, -0.1279, -0.0681, -0.0703,  0.0087, -0.0448, -0.0713,
#                       -0.0531, -0.1120, -0.1121, -0.1007, -0.0183, -0.1140, -0.0445, -0.0300],
#                      device='cuda:0')),
#              ('fc1.weight',
#               tensor([[-0.0404, -0.0328, -0.0301,  ..., -0.0427, -0.0447, -0.0555],
#                       [-0.0107, -0.0755, -0.0710,  ...,  0.0182,  0.0148,  0.0109],
#                       [ 0.1053,  0.1542,  0.1324,  ...,  0.0108,  0.0039,  0.0190],
#                       ...,
#                       [-0.0970, -0.0953, -0.1798,  ...,  0.0367,  0.0368,  0.0408],
#                       [-0.0338, -0.0234, -0.0340,  ...,  0.0006, -0.0070,  0.0009],
#                       [-0.0532, -0.0540, -0.0527,  ..., -0.0560, -0.0607, -0.0557]],
#                      device='cuda:0')),
#              ('fc1.bias',
#               tensor([-0.0652, -0.0214,  0.2035,  ..., -0.0415, -0.0619, -0.0576],
#                      device='cuda:0')),
#              ('fc2.weight',
#               tensor([[-0.0578, -0.0975, -0.0027,  ...,  0.1213, -0.0676, -0.0518],
#                       [-0.0418, -0.1868, -0.2332,  ..., -1.3626, -0.0311, -0.0520],
#                       [-0.0394, -0.2367, -0.4011,  ..., -1.6675, -0.0598, -0.0442],
#                       ...,
#                       [-0.0716, -0.4182, -0.7338,  ..., -0.2190, -0.0761, -0.0435],
#                       [-0.0852, -0.3191, -0.6075,  ..., -2.1163, -0.0376, -0.0827],
#                       [-0.0252, -0.0396, -0.3063,  ..., -0.7520, -0.0754, -0.0497]],
#                      device='cuda:0')),
#              ('fc2.bias',
#               tensor([-0.3579, -0.6424, -0.6678,  ..., -0.9888, -0.6482, -0.7391],
#                      device='cuda:0'))])

# %%
x = ext_2[2][0]#ext_1[2][0]
b = cv2.merge([x[0,:,:],x[1,:,:],x[2,:,:]])
plt.imshow(b)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
x = ext_1[2][0]#ext_1[2][0]
plt.imshow(x[6,:,:])

# %%
f_all = ext_1[2][0]
for i in range(16):
#     plt.subplots(4,4,figsize=(15,15))
    plt.subplot(4,4,i+1)
    f_img = f_all[2*i,:,:]
    plt.imshow(f_img)

# %%
b = cv2.merge([x[1,:,:],x[4,:,:],x[9,:,:]])
plt.imshow(b)

# %%
x = train_dataset.__getitem__(1000)[0]
x = x.reshape((100,100,3))
#x = cv2.merge([x[0,:,:],x[1,:,:],x[2,:,:]])
plt.imshow(x)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
ext_1[1][1]
# Out:
# tensor([1., 0., 0.,  ..., 0., 0., 0.], dtype=torch.float64)

# %% [markdown]
# ### Test_set feature extraction

# %%
exact_list=["conv2","pool2"]
test_ext_1 = []
test_ext_2 = []
j = 0
model_conv_ext.cuda()
for (data, target, name) in test_loader:
    if j == 100:
        break
    print(f'exctrating data in batch{j}')
    j += 1
    data = data.cuda()
    output = model_conv_ext(data)
    for i in range(len(output[0])):
        test_ext_1.append((output[0][i].cpu().detach().numpy(),name))
        test_ext_2.append((output[1][i].cpu().detach().numpy(),name))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-a38795043bf3> in <module>()
#       4 j = 0
#       5 model_conv_ext.cuda()
# ----> 6 for (data, target, name) in test_loader:
#       7     if j == 100:
#       8         break
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
test_ext_1 = []
test_ext_2 = []
#for (data, target, name) in train_loader:
for batch_i, (data, target) in enumerate(test_loader):
#     if batch_i == 20:
#         break
    print(f'exctrating data in batch{batch_i}')
    data = data.cuda()
    model_conv_ext.cuda()
    output = model_conv_ext(data)
    for i in range(len(output)):
        test_ext_1.append((output[i].cpu().detach().numpy(),target[i]))
        test_ext_2.append((data[i].cpu().detach().numpy(),target[i]))
# Out:
# exctrating data in batch0
# exctrating data in batch1
# exctrating data in batch2
# exctrating data in batch3
# exctrating data in batch4
# exctrating data in batch5
# exctrating data in batch6
# exctrating data in batch7
# exctrating data in batch8
# exctrating data in batch9
# exctrating data in batch10
# exctrating data in batch11
# exctrating data in batch12
# exctrating data in batch13
# exctrating data in batch14
# exctrating data in batch15
# exctrating data in batch16
# exctrating data in batch17
# exctrating data in batch18
# exctrating data in batch19
# exctrating data in batch20
# exctrating data in batch21
# exctrating data in batch22
# exctrating data in batch23
# exctrating data in batch24
# exctrating data in batch25
# exctrating data in batch26
# exctrating data in batch27
# exctrating data in batch28
# exctrating data in batch29
# exctrating data in batch30
# exctrating data in batch31
# exctrating data in batch32
# exctrating data in batch33
# exctrating data in batch34
# exctrating data in batch35
# exctrating data in batch36
# exctrating data in batch37
# exctrating data in batch38
# exctrating data in batch39
# exctrating data in batch40
# exctrating data in batch41
# exctrating data in batch42
# exctrating data in batch43
# exctrating data in batch44
# exctrating data in batch45
# exctrating data in batch46
# exctrating data in batch47
# exctrating data in batch48
# exctrating data in batch49
# exctrating data in batch50
# exctrating data in batch51
# exctrating data in batch52
# exctrating data in batch53
# exctrating data in batch54
# exctrating data in batch55
# exctrating data in batch56
# exctrating data in batch57
# exctrating data in batch58
# exctrating data in batch59
# exctrating data in batch60
# exctrating data in batch61
# exctrating data in batch62
# exctrating data in batch63
# exctrating data in batch64
# exctrating data in batch65
# exctrating data in batch66
# exctrating data in batch67
# exctrating data in batch68
# exctrating data in batch69
# exctrating data in batch70
# exctrating data in batch71
# exctrating data in batch72
# exctrating data in batch73
# exctrating data in batch74
# exctrating data in batch75
# exctrating data in batch76
# exctrating data in batch77
# exctrating data in batch78
# exctrating data in batch79
# exctrating data in batch80
# exctrating data in batch81
# exctrating data in batch82
# exctrating data in batch83
# exctrating data in batch84
# exctrating data in batch85
# exctrating data in batch86
# exctrating data in batch87
# exctrating data in batch88
# exctrating data in batch89
# exctrating data in batch90
# exctrating data in batch91
# exctrating data in batch92
# exctrating data in batch93
# exctrating data in batch94
# exctrating data in batch95
# exctrating data in batch96
# exctrating data in batch97
# exctrating data in batch98
# exctrating data in batch99
# exctrating data in batch100
# exctrating data in batch101
# exctrating data in batch102
# exctrating data in batch103
# exctrating data in batch104
# exctrating data in batch105
# exctrating data in batch106
# exctrating data in batch107
# exctrating data in batch108
# exctrating data in batch109
# exctrating data in batch110
# exctrating data in batch111
# exctrating data in batch112
# exctrating data in batch113
# exctrating data in batch114
# exctrating data in batch115
# exctrating data in batch116
# exctrating data in batch117
# exctrating data in batch118
# exctrating data in batch119
# exctrating data in batch120
# exctrating data in batch121
# exctrating data in batch122
# exctrating data in batch123
# exctrating data in batch124
# exctrating data in batch125
# exctrating data in batch126
# exctrating data in batch127
# exctrating data in batch128
# exctrating data in batch129
# exctrating data in batch130
# exctrating data in batch131
# exctrating data in batch132
# exctrating data in batch133
# exctrating data in batch134
# exctrating data in batch135
# exctrating data in batch136
# exctrating data in batch137
# exctrating data in batch138
# exctrating data in batch139
# exctrating data in batch140
# exctrating data in batch141
# exctrating data in batch142
# exctrating data in batch143
# exctrating data in batch144
# exctrating data in batch145
# exctrating data in batch146
# exctrating data in batch147
# exctrating data in batch148
# exctrating data in batch149
# exctrating data in batch150
# exctrating data in batch151
# exctrating data in batch152
# exctrating data in batch153
# exctrating data in batch154
# exctrating data in batch155
# exctrating data in batch156
# exctrating data in batch157
# exctrating data in batch158

# %%
x1 = test_ext_1[0][0]
b = cv2.merge([x1[0,:,:],x1[1,:,:],x1[2,:,:]])
plt.imshow(b)

# %%
x2 = test_set[0][0]
b = cv2.merge([x[0,:,:],x[1,:,:],x[2,:,:]])
plt.imshow(b)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
np.save("./data/simple_ext_1.npy",ext_1)
np.save("./data/simple_ext_2.npy",ext_2)
np.save("./data/simple_test_ext_1.npy",test_ext_1)
np.save("./data/simple_test_ext_2.npy",test_ext_2)

# %%
np.save("./data/untrain_cnn_ext_1_.npy", x)

# %%
np.save("./data/untrain_cnn_test_ext_2_nowhale.npy", x_ts)

# %%
len(ext_1)
# Out:
# 20288

# %%
x = np.zeros((len(ext_1), 16384))
y_n = np.zeros(len(ext_1))
for i in range(len(ext_1)):
    x[i, :]= ext_1[i][0].reshape(1, 16384)
    y_n[i] = np.argmax(ext_1[i][1].cpu().detach().numpy(), axis = 0)
x_ts = np.zeros((len(test_ext_1), 16384))
y_n_ts = np.zeros(len(test_ext_1))
for i in range(len(test_ext_1)):
    x[i, :] = test_ext_1[i][0].reshape(1, 16384)
    y_n_ts[i] = np.argmax(test_ext_1[i][1].cpu().detach().numpy(), axis = 0)

# %%
len(test_ext_1)
# Out:
# 5073

# %%
x = np.zeros((len(ext_2), 30000))
for i in range(len(ext_2)):
    x[i, :]= ext_2[i][0].reshape(1, 30000)
x_ts = np.zeros((len(test_ext_2), 30000))
for i in range(len(test_ext_2)):
    x[i, :]= test_ext_2[i][0].reshape(1, 30000)
y_n = np.argmax(y, axis = 1)
y_n_ts = np.argmax(y_ts, axis = 1)

# %% [markdown]
# ## Classification

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_ae = KNeighborsClassifier(n_neighbors=3)
knn_ae.fit(x, y_n)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#            weights='uniform')

# %%
knn_conv = KNeighborsClassifier(n_neighbors=3)
knn_conv.fit(x, y_n)
joblib.dump(knn_conv, "./model/knn_conv.m")
# Out:
# ['./model/knn_conv.m']

# %%
knn3.score(x_ts, y_n_ts)#old 3nn
# Out:
# 0.4764439187857284

# %%
knn1.score(x_ts, y_n_ts)#1nn
# Out:
# 0.00019712201852946975

# %%
knn3.score(x_ts, y_n_ts)#3nn
# Out:
# 0.4764439187857284

# %%
knn_ae.score(x_ts, y_n_ts) #ae
# Out:
# 0.3682239306130495

# %%
knn_ae.score(x_ts, y_n_ts) #ae_less
# Out:
# 0.0

# %%
joblib.dump(knn_ae, "./model/knn_ae.m")
# Out:
# ['./model/knn_ae.m']

# %%
knn2 = joblib.load("./model/knn_ae.m")
knn2.score(x_ts, y_n_ts)
# Out:
# 0.3682239306130495

# %%
from sklearn.svm import LinearSVC
svm1 = LinearSVC()
svm1.fit(x, y_n)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %%
score_svm = svm1.score(x_ts, y_n_ts)
print(score_svm)
# Out:
# 0.0005913660555884093

# %%
score_svm = svm1.score(x_ts, y_n_ts) #ae_less
print(score_svm)
# Out:
# 0.012615809185886064

# %%
joblib.dump(svm1, "./model/svm_ae.m")
# Out:
# ['./model/svm_ae.m']

# %%
svm2 = joblib.load("./model/svm_ae.m")
score_svm = svm2.score(x_ts, y_n_ts)
print(score_svm)
# Out:
# 0.0

# %% [markdown]
# ## Auto-encoder

# %%
def to_img(x):
    x = 0.5 * (x + 1)
    x = x.clamp(0, 1)
    x = x.view(x.size(0), 3, 100, 100)
    return x

# class autoencoder(nn.Module):
#     def __init__(self):
#         super(autoencoder, self).__init__()
#         self.encoder = nn.Sequential(
#             nn.Conv2d(3, 32, 7, padding=1),  # b, 16, 10, 10
#             nn.ReLU(True),
#             nn.MaxPool2d(2, stride=2),  # b, 16, 5, 5
#             nn.Conv2d(32, 64, 3, padding=1),  # b, 8, 3, 3
#             nn.ReLU(True),
#             nn.MaxPool2d(2, stride=1)  # b, 8, 2, 2
#         )
#         self.decoder = nn.Sequential(
#             nn.ConvTranspose2d(64, 32, 3),  # b, 16, 5, 5
#             nn.ReLU(True),
#             nn.ConvTranspose2d(32, 3, 7, padding=2),  # b, 8, 15, 15
# #             nn.ReLU(True),
# #             nn.ConvTranspose2d(8, 1, 2, stride=2, padding=1),  # b, 1, 28, 28
# #             nn.Tanh()
#             nn.Sigmoid()
#         )

#     def forward(self, x):
#         x = self.encoder(x)
#         x = self.decoder(x)
#         return x

# %%
class autoencoder(nn.Module):
    def __init__(self):
        super(autoencoder, self).__init__()
        self.encoder1 = nn.Sequential(
            nn.Conv2d(3, 32, 7, padding=1),  
            nn.ReLU(True))
        self.pool1 = nn.MaxPool2d(2, stride=2, return_indices=True) 
        self.encoder2 = nn.Sequential(
            nn.Conv2d(32, 64, 3, padding=1),  
            nn.ReLU(True))
        self.pool2 = nn.MaxPool2d(3, stride=1, return_indices=True)  
        self.fc1 = nn.Linear(135424, 1024)
        self.fc2 = nn.Linear(1024, 135424)
        self.unpool2 = nn.MaxUnpool2d(3, stride=1)
        self.unpool1 = nn.MaxUnpool2d(2, stride=2)
        self.decoder2 = nn.Sequential(
            nn.ConvTranspose2d(64, 32, 3, padding=1),  
            nn.ReLU(True))
        self.decoder1 = nn.Sequential(
            nn.ConvTranspose2d(32, 3, 7, padding=1),  
#             nn.ReLU(True),
#             nn.ConvTranspose2d(8, 1, 2, stride=2, padding=1), 
#             nn.Tanh()
            nn.Sigmoid()
        )

    def forward(self, x):
        x = self.encoder1(x)
        (x, ind1) = self.pool1(x)
        x = self.encoder2(x)
        (x, ind2) = self.pool2(x)
        
        x = x.view(-1, 135424)
#         print(x.shape)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        x = x.view(-1, 64, 46, 46)
        x = self.unpool2(x, ind2)
        x = self.decoder2(x)
        x = self.unpool1(x, ind1)
        x = self.decoder1(x)
        return x

# %%
num_epochs = 10
learning_rate = 1e-3
model_ae = autoencoder().cuda()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model_ae.parameters(), lr=learning_rate,
                             weight_decay=1e-5)


if not os.path.exists('./dc_img'):
    os.mkdir('./dc_img')

for epoch in range(num_epochs):
    t = time.time()
    for batch_i, (data, target) in enumerate(train_loader):
#     for data in train_loader:
        img = data
        img = Variable(img).cuda()
        # ===================forward=====================
        output = model_ae(img)
        loss = criterion(output, img)
        # ===================backward====================
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    # ===================log========================
    print()
    print('time usage {} epoch [{}/{}], loss:{:.4f}'
          .format(time.time()-t, epoch+1, num_epochs, loss.data.item()))
    if epoch == 0:
        save_image(data[0], './dc_img/oring_image.png')
    pic = to_img(output.cpu().data)
    save_image(pic[0], './dc_img/image_{}.png'.format(epoch))
# Out:
# time usage 220.29894399642944 epoch [1/10], loss:1.1561
#
# time usage 196.41710543632507 epoch [2/10], loss:1.1084
#
# time usage 197.90096783638 epoch [3/10], loss:1.4234
#
# time usage 197.2909059524536 epoch [4/10], loss:1.1579
#
# time usage 195.38659858703613 epoch [5/10], loss:1.1047
#
# time usage 189.65691757202148 epoch [6/10], loss:1.0533
#
# time usage 190.73621344566345 epoch [7/10], loss:1.2506
#
# time usage 194.84642338752747 epoch [8/10], loss:1.0363
#
# time usage 191.25704741477966 epoch [9/10], loss:1.2939
#
# time usage 198.2492973804474 epoch [10/10], loss:1.2014

# %%
# torch.save(model_ae.state_dict(), './model/conv_autoencoder_imporved.pth')

# %%
class autoencoder_ext(nn.Module):
    def __init__(self):
        super(autoencoder_ext, self).__init__()
        self.encoder1 = nn.Sequential(
            nn.Conv2d(3, 32, 7, padding=1),  
            nn.ReLU(True))
        self.pool1 = nn.MaxPool2d(2, stride=2, return_indices=True) 
        self.encoder2 = nn.Sequential(
            nn.Conv2d(32, 64, 3, padding=1),  
            nn.ReLU(True))
        self.pool2 = nn.MaxPool2d(3, stride=1, return_indices=True)  
        self.fc1 = nn.Linear(135424, 1024)
        self.fc2 = nn.Linear(1024, 135424)
        self.unpool2 = nn.MaxUnpool2d(3, stride=1)
        self.unpool1 = nn.MaxUnpool2d(2, stride=2)
        self.decoder2 = nn.Sequential(
            nn.ConvTranspose2d(64, 32, 3, padding=1),  
            nn.ReLU(True))
        self.decoder1 = nn.Sequential(
            nn.ConvTranspose2d(32, 3, 7, padding=1),  
#             nn.ReLU(True),
#             nn.ConvTranspose2d(8, 1, 2, stride=2, padding=1), 
#             nn.Tanh()
            nn.Sigmoid()
        )

    def forward(self, x):
        x = self.encoder1(x)
        (x, ind1) = self.pool1(x)
        x = self.encoder2(x)
        (x, ind2) = self.pool2(x)
        
        x = x.view(-1, 135424)
#         print(x.shape)
        x = F.relu(self.fc1(x))
#         x = self.fc2(x)
#         x = x.view(-1, 64, 46, 46)
#         x = self.unpool2(x, ind2)
#         x = self.decoder2(x)
#         x = self.unpool1(x, ind1)
#         x = self.decoder1(x)
        return x

# %%
model_ae_ext = autoencoder_ext().cuda()
model_ae_ext.load_state_dict(torch.load('./model/conv_autoencoder_imporved.pth'))

# %%
x = pic[5,:,:,:].reshape(3,100,100).numpy()
b = cv2.merge([x[0,:,:],x[1,:,:],x[2,:,:]])
plt.imshow(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-58d24c55eeb2> in <module>()
# ----> 1 x = pic[5,:,:,:].reshape(3,100,100).numpy()
#       2 b = cv2.merge([x[0,:,:],x[1,:,:],x[2,:,:]])
#       3 plt.imshow(b)
#
# NameError: name 'pic' is not defined

# %%
ext_1 = []
ext_2 = []
#for (data, target, name) in train_loader:
for batch_i, (data, target) in enumerate(train_loader):
#     if len(ext_1) >= 10000:
#         break
    print(f'exctrating data in batch{batch_i}')
    data = data.cuda()
    model_ae_ext.cuda()
    output = model_ae_ext(data)
    for i in range(len(output)):
        ext_1.append((output[i].cpu().detach().numpy(),target[i]))
        ext_2.append((data[i].cpu().detach().numpy(),target[i]))
# Out:
# exctrating data in batch0
# exctrating data in batch1
# exctrating data in batch2
# exctrating data in batch3
# exctrating data in batch4
# exctrating data in batch5
# exctrating data in batch6
# exctrating data in batch7
# exctrating data in batch8
# exctrating data in batch9
# exctrating data in batch10
# exctrating data in batch11
# exctrating data in batch12
# exctrating data in batch13
# exctrating data in batch14
# exctrating data in batch15
# exctrating data in batch16
# exctrating data in batch17
# exctrating data in batch18
# exctrating data in batch19
# exctrating data in batch20
# exctrating data in batch21
# exctrating data in batch22
# exctrating data in batch23
# exctrating data in batch24
# exctrating data in batch25
# exctrating data in batch26
# exctrating data in batch27
# exctrating data in batch28
# exctrating data in batch29
# exctrating data in batch30
# exctrating data in batch31
# exctrating data in batch32
# exctrating data in batch33
# exctrating data in batch34
# exctrating data in batch35
# exctrating data in batch36
# exctrating data in batch37
# exctrating data in batch38
# exctrating data in batch39
# exctrating data in batch40
# exctrating data in batch41
# exctrating data in batch42
# exctrating data in batch43
# exctrating data in batch44
# exctrating data in batch45
# exctrating data in batch46
# exctrating data in batch47
# exctrating data in batch48
# exctrating data in batch49
# exctrating data in batch50
# exctrating data in batch51
# exctrating data in batch52
# exctrating data in batch53
# exctrating data in batch54
# exctrating data in batch55
# exctrating data in batch56
# exctrating data in batch57
# exctrating data in batch58
# exctrating data in batch59
# exctrating data in batch60
# exctrating data in batch61
# exctrating data in batch62
# exctrating data in batch63
# exctrating data in batch64
# exctrating data in batch65
# exctrating data in batch66
# exctrating data in batch67
# exctrating data in batch68
# exctrating data in batch69
# exctrating data in batch70
# exctrating data in batch71
# exctrating data in batch72
# exctrating data in batch73
# exctrating data in batch74
# exctrating data in batch75
# exctrating data in batch76
# exctrating data in batch77
# exctrating data in batch78
# exctrating data in batch79
# exctrating data in batch80
# exctrating data in batch81
# exctrating data in batch82
# exctrating data in batch83
# exctrating data in batch84
# exctrating data in batch85
# exctrating data in batch86
# exctrating data in batch87
# exctrating data in batch88
# exctrating data in batch89
# exctrating data in batch90
# exctrating data in batch91
# exctrating data in batch92
# exctrating data in batch93
# exctrating data in batch94
# exctrating data in batch95
# exctrating data in batch96
# exctrating data in batch97
# exctrating data in batch98
# exctrating data in batch99
# exctrating data in batch100
# exctrating data in batch101
# exctrating data in batch102
# exctrating data in batch103
# exctrating data in batch104
# exctrating data in batch105
# exctrating data in batch106
# exctrating data in batch107
# exctrating data in batch108
# exctrating data in batch109
# exctrating data in batch110
# exctrating data in batch111
# exctrating data in batch112
# exctrating data in batch113
# exctrating data in batch114
# exctrating data in batch115
# exctrating data in batch116
# exctrating data in batch117
# exctrating data in batch118
# exctrating data in batch119
# exctrating data in batch120
# exctrating data in batch121
# exctrating data in batch122
# exctrating data in batch123
# exctrating data in batch124
# exctrating data in batch125
# exctrating data in batch126
# exctrating data in batch127
# exctrating data in batch128
# exctrating data in batch129
# exctrating data in batch130
# exctrating data in batch131
# exctrating data in batch132
# exctrating data in batch133
# exctrating data in batch134
# exctrating data in batch135
# exctrating data in batch136
# exctrating data in batch137
# exctrating data in batch138
# exctrating data in batch139
# exctrating data in batch140
# exctrating data in batch141
# exctrating data in batch142
# exctrating data in batch143
# exctrating data in batch144
# exctrating data in batch145
# exctrating data in batch146
# exctrating data in batch147
# exctrating data in batch148
# exctrating data in batch149
# exctrating data in batch150
# exctrating data in batch151
# exctrating data in batch152
# exctrating data in batch153
# exctrating data in batch154
# exctrating data in batch155
# exctrating data in batch156
# exctrating data in batch157
# exctrating data in batch158
# exctrating data in batch159
# exctrating data in batch160
# exctrating data in batch161
# exctrating data in batch162
# exctrating data in batch163
# exctrating data in batch164
# exctrating data in batch165
# exctrating data in batch166
# exctrating data in batch167
# exctrating data in batch168
# exctrating data in batch169
# exctrating data in batch170
# exctrating data in batch171
# exctrating data in batch172
# exctrating data in batch173
# exctrating data in batch174
# exctrating data in batch175
# exctrating data in batch176
# exctrating data in batch177
# exctrating data in batch178
# exctrating data in batch179
# exctrating data in batch180
# exctrating data in batch181
# exctrating data in batch182
# exctrating data in batch183
# exctrating data in batch184
# exctrating data in batch185
# exctrating data in batch186
# exctrating data in batch187
# exctrating data in batch188
# exctrating data in batch189
# exctrating data in batch190
# exctrating data in batch191
# exctrating data in batch192
# exctrating data in batch193
# exctrating data in batch194
# exctrating data in batch195
# exctrating data in batch196
# exctrating data in batch197
# exctrating data in batch198
# exctrating data in batch199
# exctrating data in batch200
# exctrating data in batch201
# exctrating data in batch202
# exctrating data in batch203
# exctrating data in batch204
# exctrating data in batch205
# exctrating data in batch206
# exctrating data in batch207
# exctrating data in batch208
# exctrating data in batch209
# exctrating data in batch210
# exctrating data in batch211
# exctrating data in batch212
# exctrating data in batch213
# exctrating data in batch214
# exctrating data in batch215
# exctrating data in batch216
# exctrating data in batch217
# exctrating data in batch218
# exctrating data in batch219
# exctrating data in batch220
# exctrating data in batch221
# exctrating data in batch222
# exctrating data in batch223
# exctrating data in batch224
# exctrating data in batch225
# exctrating data in batch226
# exctrating data in batch227
# exctrating data in batch228
# exctrating data in batch229
# exctrating data in batch230
# exctrating data in batch231
# exctrating data in batch232
# exctrating data in batch233
# exctrating data in batch234
# exctrating data in batch235
# exctrating data in batch236
# exctrating data in batch237
# exctrating data in batch238
# exctrating data in batch239
# exctrating data in batch240
# exctrating data in batch241
# exctrating data in batch242
# exctrating data in batch243
# exctrating data in batch244
# exctrating data in batch245
# exctrating data in batch246
# exctrating data in batch247
# exctrating data in batch248
# exctrating data in batch249
# exctrating data in batch250
# exctrating data in batch251
# exctrating data in batch252
# exctrating data in batch253
# exctrating data in batch254
# exctrating data in batch255
# exctrating data in batch256
# exctrating data in batch257
# exctrating data in batch258
# exctrating data in batch259
# exctrating data in batch260
# exctrating data in batch261
# exctrating data in batch262
# exctrating data in batch263
# exctrating data in batch264
# exctrating data in batch265
# exctrating data in batch266
# exctrating data in batch267
# exctrating data in batch268
# exctrating data in batch269
# exctrating data in batch270
# exctrating data in batch271
# exctrating data in batch272
# exctrating data in batch273
# exctrating data in batch274
# exctrating data in batch275
# exctrating data in batch276
# exctrating data in batch277
# exctrating data in batch278
# exctrating data in batch279
# exctrating data in batch280
# exctrating data in batch281
# exctrating data in batch282
# exctrating data in batch283
# exctrating data in batch284
# exctrating data in batch285
# exctrating data in batch286
# exctrating data in batch287
# exctrating data in batch288
# exctrating data in batch289
# exctrating data in batch290
# exctrating data in batch291
# exctrating data in batch292
# exctrating data in batch293
# exctrating data in batch294
# exctrating data in batch295
# exctrating data in batch296
# exctrating data in batch297
# exctrating data in batch298
# exctrating data in batch299
# exctrating data in batch300
# exctrating data in batch301
# exctrating data in batch302
# exctrating data in batch303
# exctrating data in batch304
# exctrating data in batch305
# exctrating data in batch306
# exctrating data in batch307
# exctrating data in batch308
# exctrating data in batch309
# exctrating data in batch310
# exctrating data in batch311
# exctrating data in batch312
# exctrating data in batch313
# exctrating data in batch314
# exctrating data in batch315
# exctrating data in batch316
# exctrating data in batch317
# exctrating data in batch318
# exctrating data in batch319
# exctrating data in batch320
# exctrating data in batch321
# exctrating data in batch322
# exctrating data in batch323
# exctrating data in batch324
# exctrating data in batch325
# exctrating data in batch326
# exctrating data in batch327
# exctrating data in batch328
# exctrating data in batch329
# exctrating data in batch330
# exctrating data in batch331
# exctrating data in batch332
# exctrating data in batch333
# exctrating data in batch334
# exctrating data in batch335
# exctrating data in batch336
# exctrating data in batch337
# exctrating data in batch338
# exctrating data in batch339
# exctrating data in batch340
# exctrating data in batch341
# exctrating data in batch342
# exctrating data in batch343
# exctrating data in batch344
# exctrating data in batch345
# exctrating data in batch346
# exctrating data in batch347
# exctrating data in batch348
# exctrating data in batch349
# exctrating data in batch350
# exctrating data in batch351
# exctrating data in batch352
# exctrating data in batch353
# exctrating data in batch354
# exctrating data in batch355
# exctrating data in batch356
# exctrating data in batch357
# exctrating data in batch358
# exctrating data in batch359
# exctrating data in batch360
# exctrating data in batch361
# exctrating data in batch362
# exctrating data in batch363
# exctrating data in batch364
# exctrating data in batch365
# exctrating data in batch366
# exctrating data in batch367
# exctrating data in batch368
# exctrating data in batch369
# exctrating data in batch370
# exctrating data in batch371
# exctrating data in batch372
# exctrating data in batch373
# exctrating data in batch374
# exctrating data in batch375
# exctrating data in batch376
# exctrating data in batch377
# exctrating data in batch378
# exctrating data in batch379
# exctrating data in batch380
# exctrating data in batch381
# exctrating data in batch382
# exctrating data in batch383
# exctrating data in batch384
# exctrating data in batch385
# exctrating data in batch386
# exctrating data in batch387
# exctrating data in batch388
# exctrating data in batch389
# exctrating data in batch390
# exctrating data in batch391
# exctrating data in batch392
# exctrating data in batch393
# exctrating data in batch394
# exctrating data in batch395
# exctrating data in batch396
# exctrating data in batch397
# exctrating data in batch398
# exctrating data in batch399
# exctrating data in batch400
# exctrating data in batch401
# exctrating data in batch402
# exctrating data in batch403
# exctrating data in batch404
# exctrating data in batch405
# exctrating data in batch406
# exctrating data in batch407
# exctrating data in batch408
# exctrating data in batch409
# exctrating data in batch410
# exctrating data in batch411
# exctrating data in batch412
# exctrating data in batch413
# exctrating data in batch414
# exctrating data in batch415
# exctrating data in batch416
# exctrating data in batch417
# exctrating data in batch418
# exctrating data in batch419
# exctrating data in batch420
# exctrating data in batch421
# exctrating data in batch422
# exctrating data in batch423
# exctrating data in batch424
# exctrating data in batch425
# exctrating data in batch426
# exctrating data in batch427
# exctrating data in batch428
# exctrating data in batch429
# exctrating data in batch430
# exctrating data in batch431
# exctrating data in batch432
# exctrating data in batch433
# exctrating data in batch434
# exctrating data in batch435
# exctrating data in batch436
# exctrating data in batch437
# exctrating data in batch438
# exctrating data in batch439
# exctrating data in batch440
# exctrating data in batch441
# exctrating data in batch442
# exctrating data in batch443
# exctrating data in batch444
# exctrating data in batch445
# exctrating data in batch446
# exctrating data in batch447
# exctrating data in batch448
# exctrating data in batch449
# exctrating data in batch450
# exctrating data in batch451
# exctrating data in batch452
# exctrating data in batch453
# exctrating data in batch454
# exctrating data in batch455
# exctrating data in batch456
# exctrating data in batch457
# exctrating data in batch458
# exctrating data in batch459
# exctrating data in batch460
# exctrating data in batch461
# exctrating data in batch462
# exctrating data in batch463
# exctrating data in batch464
# exctrating data in batch465
# exctrating data in batch466
# exctrating data in batch467
# exctrating data in batch468
# exctrating data in batch469
# exctrating data in batch470
# exctrating data in batch471
# exctrating data in batch472
# exctrating data in batch473
# exctrating data in batch474
# exctrating data in batch475
# exctrating data in batch476
# exctrating data in batch477
# exctrating data in batch478
# exctrating data in batch479
# exctrating data in batch480
# exctrating data in batch481
# exctrating data in batch482
# exctrating data in batch483
# exctrating data in batch484
# exctrating data in batch485
# exctrating data in batch486
# exctrating data in batch487
# exctrating data in batch488
# exctrating data in batch489
# exctrating data in batch490
# exctrating data in batch491
# exctrating data in batch492
# exctrating data in batch493
# exctrating data in batch494
# exctrating data in batch495
# exctrating data in batch496
# exctrating data in batch497
# exctrating data in batch498
# exctrating data in batch499
# exctrating data in batch500
# exctrating data in batch501
# exctrating data in batch502
# exctrating data in batch503
# exctrating data in batch504
# exctrating data in batch505
# exctrating data in batch506
# exctrating data in batch507
# exctrating data in batch508
# exctrating data in batch509
# exctrating data in batch510
# exctrating data in batch511
# exctrating data in batch512
# exctrating data in batch513
# exctrating data in batch514
# exctrating data in batch515
# exctrating data in batch516
# exctrating data in batch517
# exctrating data in batch518
# exctrating data in batch519
# exctrating data in batch520
# exctrating data in batch521
# exctrating data in batch522
# exctrating data in batch523
# exctrating data in batch524
# exctrating data in batch525
# exctrating data in batch526
# exctrating data in batch527
# exctrating data in batch528
# exctrating data in batch529
# exctrating data in batch530
# exctrating data in batch531
# exctrating data in batch532
# exctrating data in batch533
# exctrating data in batch534
# exctrating data in batch535
# exctrating data in batch536
# exctrating data in batch537
# exctrating data in batch538
# exctrating data in batch539
# exctrating data in batch540
# exctrating data in batch541
# exctrating data in batch542
# exctrating data in batch543
# exctrating data in batch544
# exctrating data in batch545
# exctrating data in batch546
# exctrating data in batch547
# exctrating data in batch548
# exctrating data in batch549
# exctrating data in batch550
# exctrating data in batch551
# exctrating data in batch552
# exctrating data in batch553
# exctrating data in batch554
# exctrating data in batch555
# exctrating data in batch556
# exctrating data in batch557
# exctrating data in batch558
# exctrating data in batch559
# exctrating data in batch560
# exctrating data in batch561
# exctrating data in batch562
# exctrating data in batch563
# exctrating data in batch564
# exctrating data in batch565
# exctrating data in batch566
# exctrating data in batch567
# exctrating data in batch568
# exctrating data in batch569
# exctrating data in batch570
# exctrating data in batch571
# exctrating data in batch572
# exctrating data in batch573
# exctrating data in batch574
# exctrating data in batch575
# exctrating data in batch576
# exctrating data in batch577
# exctrating data in batch578
# exctrating data in batch579
# exctrating data in batch580
# exctrating data in batch581
# exctrating data in batch582
# exctrating data in batch583
# exctrating data in batch584
# exctrating data in batch585
# exctrating data in batch586
# exctrating data in batch587
# exctrating data in batch588
# exctrating data in batch589
# exctrating data in batch590
# exctrating data in batch591
# exctrating data in batch592
# exctrating data in batch593
# exctrating data in batch594
# exctrating data in batch595
# exctrating data in batch596
# exctrating data in batch597
# exctrating data in batch598
# exctrating data in batch599
# exctrating data in batch600
# exctrating data in batch601
# exctrating data in batch602
# exctrating data in batch603
# exctrating data in batch604
# exctrating data in batch605
# exctrating data in batch606
# exctrating data in batch607
# exctrating data in batch608
# exctrating data in batch609
# exctrating data in batch610
# exctrating data in batch611
# exctrating data in batch612
# exctrating data in batch613
# exctrating data in batch614
# exctrating data in batch615
# exctrating data in batch616
# exctrating data in batch617
# exctrating data in batch618
# exctrating data in batch619
# exctrating data in batch620
# exctrating data in batch621
# exctrating data in batch622
# exctrating data in batch623
# exctrating data in batch624
# exctrating data in batch625
# exctrating data in batch626
# exctrating data in batch627
# exctrating data in batch628
# exctrating data in batch629
# exctrating data in batch630
# exctrating data in batch631
# exctrating data in batch632
# exctrating data in batch633

# %%
len(ext_1)
# Out:
# 20288

# %%
f_all = ext_1[51][0]
for i in range(12):
#     plt.subplots(3,4,figsize=(15,15))
    plt.subplot(3,4,i+1)
    f_img = f_all[3*i,:,:]
    plt.imshow(f_img)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-49653b748b65> in <module>()
# ----> 1 f_all = ext_1[51][0]
#       2 for i in range(12):
#       3 #     plt.subplots(3,4,figsize=(15,15))
#       4     plt.subplot(3,4,i+1)
#       5     f_img = f_all[3*i,:,:]
#
# IndexError: list index out of range

# %%
x = ext_1[51][0]
# plt.imshow(x[6,:,:]) 
ext_1[51][0].shape
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-70548cc4dce1> in <module>()
# ----> 1 x = ext_1[51][0]
#       2 # plt.imshow(x[6,:,:])
#       3 ext_1[51][0].shape
#
# IndexError: list index out of range

# %%
x = ext_2[51][0]#ext_1[2][0]
b = cv2.merge([x[0,:,:],x[1,:,:],x[2,:,:]])
plt.imshow(b)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
test_ext_1 = []
test_ext_2 = []
#for (data, target, name) in train_loader:
for batch_i, (data, target) in enumerate(test_loader):
#     if batch_i == 20:
#         break
    print(f'exctrating data in batch{batch_i}')
    data = data.cuda()
    model_ae_ext.cuda()
    output = model_ae_ext(data)
    for i in range(len(output)):
        test_ext_1.append((output[i].cpu().detach().numpy(),target[i]))
        test_ext_2.append((data[i].cpu().detach().numpy(),target[i]))
# Out:
# exctrating data in batch0
# exctrating data in batch1
# exctrating data in batch2
# exctrating data in batch3
# exctrating data in batch4
# exctrating data in batch5
# exctrating data in batch6
# exctrating data in batch7
# exctrating data in batch8
# exctrating data in batch9
# exctrating data in batch10
# exctrating data in batch11
# exctrating data in batch12
# exctrating data in batch13
# exctrating data in batch14
# exctrating data in batch15
# exctrating data in batch16
# exctrating data in batch17
# exctrating data in batch18
# exctrating data in batch19
# exctrating data in batch20
# exctrating data in batch21
# exctrating data in batch22
# exctrating data in batch23
# exctrating data in batch24
# exctrating data in batch25
# exctrating data in batch26
# exctrating data in batch27
# exctrating data in batch28
# exctrating data in batch29
# exctrating data in batch30
# exctrating data in batch31
# exctrating data in batch32
# exctrating data in batch33
# exctrating data in batch34
# exctrating data in batch35
# exctrating data in batch36
# exctrating data in batch37
# exctrating data in batch38
# exctrating data in batch39
# exctrating data in batch40
# exctrating data in batch41
# exctrating data in batch42
# exctrating data in batch43
# exctrating data in batch44
# exctrating data in batch45
# exctrating data in batch46
# exctrating data in batch47
# exctrating data in batch48
# exctrating data in batch49
# exctrating data in batch50
# exctrating data in batch51
# exctrating data in batch52
# exctrating data in batch53
# exctrating data in batch54
# exctrating data in batch55
# exctrating data in batch56
# exctrating data in batch57
# exctrating data in batch58
# exctrating data in batch59
# exctrating data in batch60
# exctrating data in batch61
# exctrating data in batch62
# exctrating data in batch63
# exctrating data in batch64
# exctrating data in batch65
# exctrating data in batch66
# exctrating data in batch67
# exctrating data in batch68
# exctrating data in batch69
# exctrating data in batch70
# exctrating data in batch71
# exctrating data in batch72
# exctrating data in batch73
# exctrating data in batch74
# exctrating data in batch75
# exctrating data in batch76
# exctrating data in batch77
# exctrating data in batch78
# exctrating data in batch79
# exctrating data in batch80
# exctrating data in batch81
# exctrating data in batch82
# exctrating data in batch83
# exctrating data in batch84
# exctrating data in batch85
# exctrating data in batch86
# exctrating data in batch87
# exctrating data in batch88
# exctrating data in batch89
# exctrating data in batch90
# exctrating data in batch91
# exctrating data in batch92
# exctrating data in batch93
# exctrating data in batch94
# exctrating data in batch95
# exctrating data in batch96
# exctrating data in batch97
# exctrating data in batch98
# exctrating data in batch99
# exctrating data in batch100
# exctrating data in batch101
# exctrating data in batch102
# exctrating data in batch103
# exctrating data in batch104
# exctrating data in batch105
# exctrating data in batch106
# exctrating data in batch107
# exctrating data in batch108
# exctrating data in batch109
# exctrating data in batch110
# exctrating data in batch111
# exctrating data in batch112
# exctrating data in batch113
# exctrating data in batch114
# exctrating data in batch115
# exctrating data in batch116
# exctrating data in batch117
# exctrating data in batch118
# exctrating data in batch119
# exctrating data in batch120
# exctrating data in batch121
# exctrating data in batch122
# exctrating data in batch123
# exctrating data in batch124
# exctrating data in batch125
# exctrating data in batch126
# exctrating data in batch127
# exctrating data in batch128
# exctrating data in batch129
# exctrating data in batch130
# exctrating data in batch131
# exctrating data in batch132
# exctrating data in batch133
# exctrating data in batch134
# exctrating data in batch135
# exctrating data in batch136
# exctrating data in batch137
# exctrating data in batch138
# exctrating data in batch139
# exctrating data in batch140
# exctrating data in batch141
# exctrating data in batch142
# exctrating data in batch143
# exctrating data in batch144
# exctrating data in batch145
# exctrating data in batch146
# exctrating data in batch147
# exctrating data in batch148
# exctrating data in batch149
# exctrating data in batch150
# exctrating data in batch151
# exctrating data in batch152
# exctrating data in batch153
# exctrating data in batch154
# exctrating data in batch155
# exctrating data in batch156
# exctrating data in batch157
# exctrating data in batch158

# %%
x = np.zeros((len(ext_1), 1024))
y_n = np.zeros(len(ext_1))
for i in range(len(ext_1)):
    x[i, :]= ext_1[i][0].reshape(1, 1024)
    y_n[i] = np.argmax(ext_1[i][1].cpu().detach().numpy(),axis=0)
x_ts = np.zeros((len(test_ext_1), 1024))
y_n_ts = np.zeros(len(test_ext_1))
for i in range(len(test_ext_1)):
    x_ts[i, :]= test_ext_1[i][0].reshape(1, 1024)
    y_n_ts[i] = np.argmax(test_ext_1[i][1].cpu().detach().numpy(),axis=0)

# %%
y_n_ts.shape
# Out:
# (5073,)

# %% [markdown]
# ## Resnet18 feature extraction

# %%
class WhaleDataset(Dataset):
    def __init__(self, datafolder, datatype='train', df=None, transform = transforms.Compose([transforms.ToTensor()]), y=None):
        self.datafolder = datafolder
        self.datatype = datatype
        self.y = y
        if self.datatype == 'train':
            self.df = df.values
        self.image_files_list = [s for s in os.listdir(datafolder)]
        self.transform = transform


    def __len__(self):
        return len(self.image_files_list)
    
    def __getitem__(self, idx):
        if self.datatype == 'train':
            img_name = os.path.join(self.datafolder, self.df[idx - 1][0])
            label = self.y[idx - 1]
            
        elif self.datatype == 'test':
            img_name = os.path.join(self.datafolder, self.image_files_list[idx - 1])
            label = np.zeros((4571,))

        image = Image.open(img_name).convert('RGB')
        image = self.transform(image)
        if self.datatype == 'train':
            return image, label
        elif self.datatype == 'test':
            # so that the images will be in a correct order
            return image, label, self.image_files_list[idx]

# %%
data_transforms = transforms.Compose([
                                      transforms.RandomResizedCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                             std=[0.229, 0.224, 0.225])
    ])
data_transforms_test = transforms.Compose([
                                           transforms.RandomResizedCrop(224),
                                           transforms.ToTensor(),
                                           transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                                 std=[0.229, 0.224, 0.225])
])

# %%
train_dataset = WhaleDataset(datafolder='./whaletrain/', datatype='train', df=train_df, transform=data_transforms, y=y)
test_set = WhaleDataset(datafolder='./whaletest/', datatype='train', df=test_df, transform=data_transforms_test,y = y_ts)
#test
train_sampler = SubsetRandomSampler(list(range(len(os.listdir('./whaletrain')))))
valid_sampler = SubsetRandomSampler(list(range(len(os.listdir('./whaletest')))))
batch_size = 10
num_workers = 0

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, sampler=train_sampler, num_workers=num_workers)
# less size for test loader.
test_loader = torch.utils.data.DataLoader(test_set, batch_size=32, num_workers=num_workers)

# %%
class ResidualBlock(nn.Module):
    def __init__(self, inchannel, outchannel, stride=1):
        super(ResidualBlock, self).__init__()
        self.left = nn.Sequential(
            nn.Conv2d(inchannel, outchannel, kernel_size=3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(outchannel),
            nn.ReLU(inplace=True),
            nn.Conv2d(outchannel, outchannel, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(outchannel)
        )
        self.shortcut = nn.Sequential()
        if stride != 1 or inchannel != outchannel:
            self.shortcut = nn.Sequential(
                nn.Conv2d(inchannel, outchannel, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(outchannel)
            )

    def forward(self, x):
        out = self.left(x)
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class Res_ext(nn.Module):
    def __init__(self, ResidualBlock, num_classes=4571):
        super(Res_ext, self).__init__()
        self.inchannel = 64
        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(),
        )
        self.layer1 = self.make_layer(ResidualBlock, 64,  2, stride=1)
        self.layer2 = self.make_layer(ResidualBlock, 128, 2, stride=2)
        self.layer3 = self.make_layer(ResidualBlock, 256, 2, stride=2)
        self.layer4 = self.make_layer(ResidualBlock, 512, 2, stride=2)
        self.fc = nn.Linear(512, num_classes)

    def make_layer(self, block, channels, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)   #strides=[1,1]
        layers = []
        for stride in strides:
            layers.append(block(self.inchannel, channels, stride))
            self.inchannel = channels
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.conv1(x)
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
#         out = out.view(out.size(0), -1)
#         out = self.fc(out)
        return out

# %%
model_conv_ext_res = Res_ext(ResidualBlock)
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model_conv_ext_res.parameters(), lr=0.01)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)

# %%
ext_1 = []
ext_2 = []
#for (data, target, name) in train_loader:
for batch_i, (data, target) in enumerate(train_loader):
    if batch_i == 2000:
        break
    print(f'exctrating data in batch{batch_i}')
    data = data.cuda()
    model_conv_ext_res.cuda()
    output = model_conv_ext_res(data)
    for i in range(len(output)):
        ext_1.append((output[i].cpu().detach().numpy(),target[i]))
        ext_2.append((data[i].cpu().detach().numpy(),target[i]))
# Out:
# exctrating data in batch0
# exctrating data in batch1
# exctrating data in batch2
# exctrating data in batch3
# exctrating data in batch4
# exctrating data in batch5
# exctrating data in batch6
# exctrating data in batch7
# exctrating data in batch8
# exctrating data in batch9
# exctrating data in batch10
# exctrating data in batch11
# exctrating data in batch12
# exctrating data in batch13
# exctrating data in batch14
# exctrating data in batch15
# exctrating data in batch16
# exctrating data in batch17
# exctrating data in batch18
# exctrating data in batch19
# exctrating data in batch20
# exctrating data in batch21
# exctrating data in batch22
# exctrating data in batch23
# exctrating data in batch24
# exctrating data in batch25
# exctrating data in batch26
# exctrating data in batch27
# exctrating data in batch28
# exctrating data in batch29
# exctrating data in batch30
# exctrating data in batch31
# exctrating data in batch32
# exctrating data in batch33
# exctrating data in batch34
# exctrating data in batch35
# exctrating data in batch36
# exctrating data in batch37
# exctrating data in batch38
# exctrating data in batch39
# exctrating data in batch40
# exctrating data in batch41
# exctrating data in batch42
# exctrating data in batch43
# exctrating data in batch44
# exctrating data in batch45
# exctrating data in batch46
# exctrating data in batch47
# exctrating data in batch48
# exctrating data in batch49
# exctrating data in batch50
# exctrating data in batch51
# exctrating data in batch52
# exctrating data in batch53
# exctrating data in batch54
# exctrating data in batch55
# exctrating data in batch56
# exctrating data in batch57
# exctrating data in batch58
# exctrating data in batch59
# exctrating data in batch60
# exctrating data in batch61
# exctrating data in batch62
# exctrating data in batch63
# exctrating data in batch64
# exctrating data in batch65
# exctrating data in batch66
# exctrating data in batch67
# exctrating data in batch68
# exctrating data in batch69
# exctrating data in batch70
# exctrating data in batch71
# exctrating data in batch72
# exctrating data in batch73
# exctrating data in batch74
# exctrating data in batch75
# exctrating data in batch76
# exctrating data in batch77
# exctrating data in batch78
# exctrating data in batch79
# exctrating data in batch80
# exctrating data in batch81
# exctrating data in batch82
# exctrating data in batch83
# exctrating data in batch84
# exctrating data in batch85
# exctrating data in batch86
# exctrating data in batch87
# exctrating data in batch88
# exctrating data in batch89
# exctrating data in batch90
# exctrating data in batch91
# exctrating data in batch92
# exctrating data in batch93
# exctrating data in batch94
# exctrating data in batch95
# exctrating data in batch96
# exctrating data in batch97
# exctrating data in batch98
# exctrating data in batch99
# exctrating data in batch100
# exctrating data in batch101
# exctrating data in batch102
# exctrating data in batch103
# exctrating data in batch104
# exctrating data in batch105
# exctrating data in batch106
# exctrating data in batch107
# exctrating data in batch108
# exctrating data in batch109
# exctrating data in batch110
# exctrating data in batch111
# exctrating data in batch112
# exctrating data in batch113
# exctrating data in batch114
# exctrating data in batch115
# exctrating data in batch116
# exctrating data in batch117
# exctrating data in batch118
# exctrating data in batch119
# exctrating data in batch120
# exctrating data in batch121
# exctrating data in batch122
# exctrating data in batch123
# exctrating data in batch124
# exctrating data in batch125
# exctrating data in batch126
# exctrating data in batch127
# exctrating data in batch128
# exctrating data in batch129
# exctrating data in batch130
# exctrating data in batch131
# exctrating data in batch132
# exctrating data in batch133
# exctrating data in batch134
# exctrating data in batch135
# exctrating data in batch136
# exctrating data in batch137
# exctrating data in batch138
# exctrating data in batch139
# exctrating data in batch140
# exctrating data in batch141
# exctrating data in batch142
# exctrating data in batch143
# exctrating data in batch144
# exctrating data in batch145
# exctrating data in batch146
# exctrating data in batch147
# exctrating data in batch148
# exctrating data in batch149
# exctrating data in batch150
# exctrating data in batch151
# exctrating data in batch152
# exctrating data in batch153
# exctrating data in batch154
# exctrating data in batch155
# exctrating data in batch156
# exctrating data in batch157
# exctrating data in batch158
# exctrating data in batch159
# exctrating data in batch160
# exctrating data in batch161
# exctrating data in batch162
# exctrating data in batch163
# exctrating data in batch164
# exctrating data in batch165
# exctrating data in batch166
# exctrating data in batch167
# exctrating data in batch168
# exctrating data in batch169
# exctrating data in batch170
# exctrating data in batch171
# exctrating data in batch172
# exctrating data in batch173
# exctrating data in batch174
# exctrating data in batch175
# exctrating data in batch176
# exctrating data in batch177
# exctrating data in batch178
# exctrating data in batch179
# exctrating data in batch180
# exctrating data in batch181
# exctrating data in batch182
# exctrating data in batch183
# exctrating data in batch184
# exctrating data in batch185
# exctrating data in batch186
# exctrating data in batch187
# exctrating data in batch188
# exctrating data in batch189
# exctrating data in batch190
# exctrating data in batch191
# exctrating data in batch192
# exctrating data in batch193
# exctrating data in batch194
# exctrating data in batch195
# exctrating data in batch196
# exctrating data in batch197
# exctrating data in batch198
# exctrating data in batch199
# exctrating data in batch200
# exctrating data in batch201
# exctrating data in batch202
# exctrating data in batch203
# exctrating data in batch204
# exctrating data in batch205
# exctrating data in batch206
# exctrating data in batch207
# exctrating data in batch208
# exctrating data in batch209
# exctrating data in batch210
# exctrating data in batch211
# exctrating data in batch212
# exctrating data in batch213
# exctrating data in batch214
# exctrating data in batch215
# exctrating data in batch216
# exctrating data in batch217
# exctrating data in batch218
# exctrating data in batch219
# exctrating data in batch220
# exctrating data in batch221
# exctrating data in batch222
# exctrating data in batch223
# exctrating data in batch224
# exctrating data in batch225
# exctrating data in batch226
# exctrating data in batch227
# exctrating data in batch228
# exctrating data in batch229
# exctrating data in batch230
# exctrating data in batch231
# exctrating data in batch232
# exctrating data in batch233
# exctrating data in batch234
# exctrating data in batch235
# exctrating data in batch236
# exctrating data in batch237
# exctrating data in batch238
# exctrating data in batch239
# exctrating data in batch240
# exctrating data in batch241
# exctrating data in batch242
# exctrating data in batch243
# exctrating data in batch244
# exctrating data in batch245
# exctrating data in batch246
# exctrating data in batch247
# exctrating data in batch248
# exctrating data in batch249
# exctrating data in batch250
# exctrating data in batch251
# exctrating data in batch252
# exctrating data in batch253
# exctrating data in batch254
# exctrating data in batch255
# exctrating data in batch256
# exctrating data in batch257
# exctrating data in batch258
# exctrating data in batch259
# exctrating data in batch260
# exctrating data in batch261
# exctrating data in batch262
# exctrating data in batch263
# exctrating data in batch264
# exctrating data in batch265
# exctrating data in batch266
# exctrating data in batch267
# exctrating data in batch268
# exctrating data in batch269
# exctrating data in batch270
# exctrating data in batch271
# exctrating data in batch272
# exctrating data in batch273
# exctrating data in batch274
# exctrating data in batch275
# exctrating data in batch276
# exctrating data in batch277
# exctrating data in batch278
# exctrating data in batch279
# exctrating data in batch280
# exctrating data in batch281
# exctrating data in batch282
# exctrating data in batch283
# exctrating data in batch284
# exctrating data in batch285
# exctrating data in batch286
# exctrating data in batch287
# exctrating data in batch288
# exctrating data in batch289
# exctrating data in batch290
# exctrating data in batch291
# exctrating data in batch292
# exctrating data in batch293
# exctrating data in batch294
# exctrating data in batch295
# exctrating data in batch296
# exctrating data in batch297
# exctrating data in batch298
# exctrating data in batch299
# exctrating data in batch300
# exctrating data in batch301
# exctrating data in batch302
# exctrating data in batch303
# exctrating data in batch304
# exctrating data in batch305
# exctrating data in batch306
# exctrating data in batch307
# exctrating data in batch308
# exctrating data in batch309
# exctrating data in batch310
# exctrating data in batch311
# exctrating data in batch312
# exctrating data in batch313
# exctrating data in batch314
# exctrating data in batch315
# exctrating data in batch316
# exctrating data in batch317
# exctrating data in batch318
# exctrating data in batch319
# exctrating data in batch320
# exctrating data in batch321
# exctrating data in batch322
# exctrating data in batch323
# exctrating data in batch324
# exctrating data in batch325
# exctrating data in batch326
# exctrating data in batch327
# exctrating data in batch328
# exctrating data in batch329
# exctrating data in batch330
# exctrating data in batch331
# exctrating data in batch332
# exctrating data in batch333
# exctrating data in batch334
# exctrating data in batch335
# exctrating data in batch336
# exctrating data in batch337
# exctrating data in batch338
# exctrating data in batch339
# exctrating data in batch340
# exctrating data in batch341
# exctrating data in batch342
# exctrating data in batch343
# exctrating data in batch344
# exctrating data in batch345
# exctrating data in batch346
# exctrating data in batch347
# exctrating data in batch348
# exctrating data in batch349
# exctrating data in batch350
# exctrating data in batch351
# exctrating data in batch352
# exctrating data in batch353
# exctrating data in batch354
# exctrating data in batch355
# exctrating data in batch356
# exctrating data in batch357
# exctrating data in batch358
# exctrating data in batch359
# exctrating data in batch360
# exctrating data in batch361
# exctrating data in batch362
# exctrating data in batch363
# exctrating data in batch364
# exctrating data in batch365
# exctrating data in batch366
# exctrating data in batch367
# exctrating data in batch368
# exctrating data in batch369
# exctrating data in batch370
# exctrating data in batch371
# exctrating data in batch372
# exctrating data in batch373
# exctrating data in batch374
# exctrating data in batch375
# exctrating data in batch376
# exctrating data in batch377
# exctrating data in batch378
# exctrating data in batch379
# exctrating data in batch380
# exctrating data in batch381
# exctrating data in batch382
# exctrating data in batch383
# exctrating data in batch384
# exctrating data in batch385
# exctrating data in batch386
# exctrating data in batch387
# exctrating data in batch388
# exctrating data in batch389
# exctrating data in batch390
# exctrating data in batch391
# exctrating data in batch392
# exctrating data in batch393
# exctrating data in batch394
# exctrating data in batch395
# exctrating data in batch396
# exctrating data in batch397
# exctrating data in batch398
# exctrating data in batch399
# exctrating data in batch400
# exctrating data in batch401
# exctrating data in batch402
# exctrating data in batch403
# exctrating data in batch404
# exctrating data in batch405
# exctrating data in batch406
# exctrating data in batch407
# exctrating data in batch408
# exctrating data in batch409
# exctrating data in batch410
# exctrating data in batch411
# exctrating data in batch412
# exctrating data in batch413
# exctrating data in batch414
# exctrating data in batch415
# exctrating data in batch416
# exctrating data in batch417
# exctrating data in batch418
# exctrating data in batch419
# exctrating data in batch420
# exctrating data in batch421
# exctrating data in batch422
# exctrating data in batch423
# exctrating data in batch424
# exctrating data in batch425
# exctrating data in batch426
# exctrating data in batch427
# exctrating data in batch428
# exctrating data in batch429
# exctrating data in batch430
# exctrating data in batch431
# exctrating data in batch432
# exctrating data in batch433
# exctrating data in batch434
# exctrating data in batch435
# exctrating data in batch436
# exctrating data in batch437
# exctrating data in batch438
# exctrating data in batch439
# exctrating data in batch440
# exctrating data in batch441
# exctrating data in batch442
# exctrating data in batch443
# exctrating data in batch444
# exctrating data in batch445
# exctrating data in batch446
# exctrating data in batch447
# exctrating data in batch448
# exctrating data in batch449
# exctrating data in batch450
# exctrating data in batch451
# exctrating data in batch452
# exctrating data in batch453
# exctrating data in batch454
# exctrating data in batch455
# exctrating data in batch456
# exctrating data in batch457
# exctrating data in batch458
# exctrating data in batch459
# exctrating data in batch460
# exctrating data in batch461
# exctrating data in batch462
# exctrating data in batch463
# exctrating data in batch464
# exctrating data in batch465
# exctrating data in batch466
# exctrating data in batch467
# exctrating data in batch468
# exctrating data in batch469
# exctrating data in batch470
# exctrating data in batch471
# exctrating data in batch472
# exctrating data in batch473
# exctrating data in batch474
# exctrating data in batch475
# exctrating data in batch476
# exctrating data in batch477
# exctrating data in batch478
# exctrating data in batch479
# exctrating data in batch480
# exctrating data in batch481
# exctrating data in batch482
# exctrating data in batch483
# exctrating data in batch484
# exctrating data in batch485
# exctrating data in batch486
# exctrating data in batch487
# exctrating data in batch488
# exctrating data in batch489
# exctrating data in batch490
# exctrating data in batch491
# exctrating data in batch492
# exctrating data in batch493
# exctrating data in batch494
# exctrating data in batch495
# exctrating data in batch496
# exctrating data in batch497
# exctrating data in batch498
# exctrating data in batch499
# exctrating data in batch500
# exctrating data in batch501
# exctrating data in batch502
# exctrating data in batch503
# exctrating data in batch504
# exctrating data in batch505
# exctrating data in batch506
# exctrating data in batch507
# exctrating data in batch508
# exctrating data in batch509
# exctrating data in batch510
# exctrating data in batch511
# exctrating data in batch512
# exctrating data in batch513
# exctrating data in batch514
# exctrating data in batch515
# exctrating data in batch516
# exctrating data in batch517
# exctrating data in batch518
# exctrating data in batch519
# exctrating data in batch520
# exctrating data in batch521
# exctrating data in batch522
# exctrating data in batch523
# exctrating data in batch524
# exctrating data in batch525
# exctrating data in batch526
# exctrating data in batch527
# exctrating data in batch528
# exctrating data in batch529
# exctrating data in batch530
# exctrating data in batch531
# exctrating data in batch532
# exctrating data in batch533
# exctrating data in batch534
# exctrating data in batch535
# exctrating data in batch536
# exctrating data in batch537
# exctrating data in batch538
# exctrating data in batch539
# exctrating data in batch540
# exctrating data in batch541
# exctrating data in batch542
# exctrating data in batch543
# exctrating data in batch544
# exctrating data in batch545
# exctrating data in batch546
# exctrating data in batch547
# exctrating data in batch548
# exctrating data in batch549
# exctrating data in batch550
# exctrating data in batch551
# exctrating data in batch552
# exctrating data in batch553
# exctrating data in batch554
# exctrating data in batch555
# exctrating data in batch556
# exctrating data in batch557
# exctrating data in batch558
# exctrating data in batch559
# exctrating data in batch560
# exctrating data in batch561
# exctrating data in batch562
# exctrating data in batch563
# exctrating data in batch564
# exctrating data in batch565
# exctrating data in batch566
# exctrating data in batch567
# exctrating data in batch568
# exctrating data in batch569
# exctrating data in batch570
# exctrating data in batch571
# exctrating data in batch572
# exctrating data in batch573
# exctrating data in batch574
# exctrating data in batch575
# exctrating data in batch576
# exctrating data in batch577
# exctrating data in batch578
# exctrating data in batch579
# exctrating data in batch580
# exctrating data in batch581
# exctrating data in batch582
# exctrating data in batch583
# exctrating data in batch584
# exctrating data in batch585
# exctrating data in batch586
# exctrating data in batch587
# exctrating data in batch588
# exctrating data in batch589
# exctrating data in batch590
# exctrating data in batch591
# exctrating data in batch592
# exctrating data in batch593
# exctrating data in batch594
# exctrating data in batch595
# exctrating data in batch596
# exctrating data in batch597
# exctrating data in batch598
# exctrating data in batch599
# exctrating data in batch600
# exctrating data in batch601
# exctrating data in batch602
# exctrating data in batch603
# exctrating data in batch604
# exctrating data in batch605
# exctrating data in batch606
# exctrating data in batch607
# exctrating data in batch608
# exctrating data in batch609
# exctrating data in batch610
# exctrating data in batch611
# exctrating data in batch612
# exctrating data in batch613
# exctrating data in batch614
# exctrating data in batch615
# exctrating data in batch616
# exctrating data in batch617
# exctrating data in batch618
# exctrating data in batch619
# exctrating data in batch620
# exctrating data in batch621
# exctrating data in batch622
# exctrating data in batch623
# exctrating data in batch624
# exctrating data in batch625
# exctrating data in batch626
# exctrating data in batch627
# exctrating data in batch628
# exctrating data in batch629
# exctrating data in batch630
# exctrating data in batch631
# exctrating data in batch632
# exctrating data in batch633
# exctrating data in batch634
# exctrating data in batch635
# exctrating data in batch636
# exctrating data in batch637
# exctrating data in batch638
# exctrating data in batch639
# exctrating data in batch640
# exctrating data in batch641
# exctrating data in batch642
# exctrating data in batch643
# exctrating data in batch644
# exctrating data in batch645
# exctrating data in batch646
# exctrating data in batch647
# exctrating data in batch648
# exctrating data in batch649
# exctrating data in batch650
# exctrating data in batch651
# exctrating data in batch652
# exctrating data in batch653
# exctrating data in batch654
# exctrating data in batch655
# exctrating data in batch656
# exctrating data in batch657
# exctrating data in batch658
# exctrating data in batch659
# exctrating data in batch660
# exctrating data in batch661
# exctrating data in batch662
# exctrating data in batch663
# exctrating data in batch664
# exctrating data in batch665
# exctrating data in batch666
# exctrating data in batch667
# exctrating data in batch668
# exctrating data in batch669
# exctrating data in batch670
# exctrating data in batch671
# exctrating data in batch672
# exctrating data in batch673
# exctrating data in batch674
# exctrating data in batch675
# exctrating data in batch676
# exctrating data in batch677
# exctrating data in batch678
# exctrating data in batch679
# exctrating data in batch680
# exctrating data in batch681
# exctrating data in batch682
# exctrating data in batch683
# exctrating data in batch684
# exctrating data in batch685
# exctrating data in batch686
# exctrating data in batch687
# exctrating data in batch688
# exctrating data in batch689
# exctrating data in batch690
# exctrating data in batch691
# exctrating data in batch692
# exctrating data in batch693
# exctrating data in batch694
# exctrating data in batch695
# exctrating data in batch696
# exctrating data in batch697
# exctrating data in batch698
# exctrating data in batch699
# exctrating data in batch700
# exctrating data in batch701
# exctrating data in batch702
# exctrating data in batch703
# exctrating data in batch704
# exctrating data in batch705
# exctrating data in batch706
# exctrating data in batch707
# exctrating data in batch708
# exctrating data in batch709
# exctrating data in batch710
# exctrating data in batch711
# exctrating data in batch712
# exctrating data in batch713
# exctrating data in batch714
# exctrating data in batch715
# exctrating data in batch716
# exctrating data in batch717
# exctrating data in batch718
# exctrating data in batch719
# exctrating data in batch720
# exctrating data in batch721
# exctrating data in batch722
# exctrating data in batch723
# exctrating data in batch724
# exctrating data in batch725
# exctrating data in batch726
# exctrating data in batch727
# exctrating data in batch728
# exctrating data in batch729
# exctrating data in batch730
# exctrating data in batch731
# exctrating data in batch732
# exctrating data in batch733
# exctrating data in batch734
# exctrating data in batch735
# exctrating data in batch736
# exctrating data in batch737
# exctrating data in batch738
# exctrating data in batch739
# exctrating data in batch740
# exctrating data in batch741
# exctrating data in batch742
# exctrating data in batch743
# exctrating data in batch744
# exctrating data in batch745
# exctrating data in batch746
# exctrating data in batch747
# exctrating data in batch748
# exctrating data in batch749
# exctrating data in batch750
# exctrating data in batch751
# exctrating data in batch752
# exctrating data in batch753
# exctrating data in batch754
# exctrating data in batch755
# exctrating data in batch756
# exctrating data in batch757
# exctrating data in batch758
# exctrating data in batch759
# exctrating data in batch760
# exctrating data in batch761
# exctrating data in batch762
# exctrating data in batch763
# exctrating data in batch764
# exctrating data in batch765
# exctrating data in batch766
# exctrating data in batch767
# exctrating data in batch768
# exctrating data in batch769
# exctrating data in batch770
# exctrating data in batch771
# exctrating data in batch772
# exctrating data in batch773
# exctrating data in batch774
# exctrating data in batch775
# exctrating data in batch776
# exctrating data in batch777
# exctrating data in batch778
# exctrating data in batch779
# exctrating data in batch780
# exctrating data in batch781
# exctrating data in batch782
# exctrating data in batch783
# exctrating data in batch784
# exctrating data in batch785
# exctrating data in batch786
# exctrating data in batch787
# exctrating data in batch788
# exctrating data in batch789
# exctrating data in batch790
# exctrating data in batch791
# exctrating data in batch792
# exctrating data in batch793
# exctrating data in batch794
# exctrating data in batch795
# exctrating data in batch796
# exctrating data in batch797
# exctrating data in batch798
# exctrating data in batch799
# exctrating data in batch800
# exctrating data in batch801
# exctrating data in batch802
# exctrating data in batch803
# exctrating data in batch804
# exctrating data in batch805
# exctrating data in batch806
# exctrating data in batch807
# exctrating data in batch808
# exctrating data in batch809
# exctrating data in batch810
# exctrating data in batch811
# exctrating data in batch812
# exctrating data in batch813
# exctrating data in batch814
# exctrating data in batch815
# exctrating data in batch816
# exctrating data in batch817
# exctrating data in batch818
# exctrating data in batch819
# exctrating data in batch820
# exctrating data in batch821
# exctrating data in batch822
# exctrating data in batch823
# exctrating data in batch824
# exctrating data in batch825
# exctrating data in batch826
# exctrating data in batch827
# exctrating data in batch828
# exctrating data in batch829
# exctrating data in batch830
# exctrating data in batch831
# exctrating data in batch832
# exctrating data in batch833
# exctrating data in batch834
# exctrating data in batch835
# exctrating data in batch836
# exctrating data in batch837
# exctrating data in batch838
# exctrating data in batch839
# exctrating data in batch840
# exctrating data in batch841
# exctrating data in batch842
# exctrating data in batch843
# exctrating data in batch844
# exctrating data in batch845
# exctrating data in batch846
# exctrating data in batch847
# exctrating data in batch848
# exctrating data in batch849
# exctrating data in batch850
# exctrating data in batch851
# exctrating data in batch852
# exctrating data in batch853
# exctrating data in batch854
# exctrating data in batch855
# exctrating data in batch856
# exctrating data in batch857
# exctrating data in batch858
# exctrating data in batch859
# exctrating data in batch860
# exctrating data in batch861
# exctrating data in batch862
# exctrating data in batch863
# exctrating data in batch864
# exctrating data in batch865
# exctrating data in batch866
# exctrating data in batch867
# exctrating data in batch868
# exctrating data in batch869
# exctrating data in batch870
# exctrating data in batch871
# exctrating data in batch872
# exctrating data in batch873
# exctrating data in batch874
# exctrating data in batch875
# exctrating data in batch876
# exctrating data in batch877
# exctrating data in batch878
# exctrating data in batch879
# exctrating data in batch880
# exctrating data in batch881
# exctrating data in batch882
# exctrating data in batch883
# exctrating data in batch884
# exctrating data in batch885
# exctrating data in batch886
# exctrating data in batch887
# exctrating data in batch888
# exctrating data in batch889
# exctrating data in batch890
# exctrating data in batch891
# exctrating data in batch892
# exctrating data in batch893
# exctrating data in batch894
# exctrating data in batch895
# exctrating data in batch896
# exctrating data in batch897
# exctrating data in batch898
# exctrating data in batch899
# exctrating data in batch900
# exctrating data in batch901
# exctrating data in batch902
# exctrating data in batch903
# exctrating data in batch904
# exctrating data in batch905
# exctrating data in batch906
# exctrating data in batch907
# exctrating data in batch908
# exctrating data in batch909
# exctrating data in batch910
# exctrating data in batch911
# exctrating data in batch912
# exctrating data in batch913
# exctrating data in batch914
# exctrating data in batch915
# exctrating data in batch916
# exctrating data in batch917
# exctrating data in batch918
# exctrating data in batch919
# exctrating data in batch920
# exctrating data in batch921
# exctrating data in batch922
# exctrating data in batch923
# exctrating data in batch924
# exctrating data in batch925
# exctrating data in batch926
# exctrating data in batch927
# exctrating data in batch928
# exctrating data in batch929
# exctrating data in batch930
# exctrating data in batch931
# exctrating data in batch932
# exctrating data in batch933
# exctrating data in batch934
# exctrating data in batch935
# exctrating data in batch936
# exctrating data in batch937
# exctrating data in batch938
# exctrating data in batch939
# exctrating data in batch940
# exctrating data in batch941
# exctrating data in batch942
# exctrating data in batch943
# exctrating data in batch944
# exctrating data in batch945
# exctrating data in batch946
# exctrating data in batch947
# exctrating data in batch948
# exctrating data in batch949
# exctrating data in batch950
# exctrating data in batch951
# exctrating data in batch952
# exctrating data in batch953
# exctrating data in batch954
# exctrating data in batch955
# exctrating data in batch956
# exctrating data in batch957
# exctrating data in batch958
# exctrating data in batch959
# exctrating data in batch960
# exctrating data in batch961
# exctrating data in batch962
# exctrating data in batch963
# exctrating data in batch964
# exctrating data in batch965
# exctrating data in batch966
# exctrating data in batch967
# exctrating data in batch968
# exctrating data in batch969
# exctrating data in batch970
# exctrating data in batch971
# exctrating data in batch972
# exctrating data in batch973
# exctrating data in batch974
# exctrating data in batch975
# exctrating data in batch976
# exctrating data in batch977
# exctrating data in batch978
# exctrating data in batch979
# exctrating data in batch980
# exctrating data in batch981
# exctrating data in batch982
# exctrating data in batch983
# exctrating data in batch984
# exctrating data in batch985
# exctrating data in batch986
# exctrating data in batch987
# exctrating data in batch988
# exctrating data in batch989
# exctrating data in batch990
# exctrating data in batch991
# exctrating data in batch992
# exctrating data in batch993
# exctrating data in batch994
# exctrating data in batch995
# exctrating data in batch996
# exctrating data in batch997
# exctrating data in batch998
# exctrating data in batch999
# exctrating data in batch1000
# exctrating data in batch1001
# exctrating data in batch1002
# exctrating data in batch1003
# exctrating data in batch1004
# exctrating data in batch1005
# exctrating data in batch1006
# exctrating data in batch1007
# exctrating data in batch1008
# exctrating data in batch1009
# exctrating data in batch1010
# exctrating data in batch1011
# exctrating data in batch1012
# exctrating data in batch1013
# exctrating data in batch1014
# exctrating data in batch1015
# exctrating data in batch1016
# exctrating data in batch1017
# exctrating data in batch1018
# exctrating data in batch1019
# exctrating data in batch1020
# exctrating data in batch1021
# exctrating data in batch1022
# exctrating data in batch1023
# exctrating data in batch1024
# exctrating data in batch1025
# exctrating data in batch1026
# exctrating data in batch1027
# exctrating data in batch1028
# exctrating data in batch1029
# exctrating data in batch1030
# exctrating data in batch1031
# exctrating data in batch1032
# exctrating data in batch1033
# exctrating data in batch1034
# exctrating data in batch1035
# exctrating data in batch1036
# exctrating data in batch1037
# exctrating data in batch1038
# exctrating data in batch1039
# exctrating data in batch1040
# exctrating data in batch1041
# exctrating data in batch1042
# exctrating data in batch1043
# exctrating data in batch1044
# exctrating data in batch1045
# exctrating data in batch1046
# exctrating data in batch1047
# exctrating data in batch1048
# exctrating data in batch1049
# exctrating data in batch1050
# exctrating data in batch1051
# exctrating data in batch1052
# exctrating data in batch1053
# exctrating data in batch1054
# exctrating data in batch1055
# exctrating data in batch1056
# exctrating data in batch1057
# exctrating data in batch1058
# exctrating data in batch1059
# exctrating data in batch1060
# exctrating data in batch1061
# exctrating data in batch1062
# exctrating data in batch1063
# exctrating data in batch1064
# exctrating data in batch1065
# exctrating data in batch1066
# exctrating data in batch1067
# exctrating data in batch1068
# exctrating data in batch1069
# exctrating data in batch1070
# exctrating data in batch1071
# exctrating data in batch1072
# exctrating data in batch1073
# exctrating data in batch1074
# exctrating data in batch1075
# exctrating data in batch1076
# exctrating data in batch1077
# exctrating data in batch1078
# exctrating data in batch1079
# exctrating data in batch1080
# exctrating data in batch1081
# exctrating data in batch1082
# exctrating data in batch1083
# exctrating data in batch1084
# exctrating data in batch1085
# exctrating data in batch1086
# exctrating data in batch1087
# exctrating data in batch1088
# exctrating data in batch1089
# exctrating data in batch1090
# exctrating data in batch1091
# exctrating data in batch1092
# exctrating data in batch1093
# exctrating data in batch1094
# exctrating data in batch1095
# exctrating data in batch1096
# exctrating data in batch1097
# exctrating data in batch1098
# exctrating data in batch1099
# exctrating data in batch1100
# exctrating data in batch1101
# exctrating data in batch1102
# exctrating data in batch1103
# exctrating data in batch1104
# exctrating data in batch1105
# exctrating data in batch1106
# exctrating data in batch1107
# exctrating data in batch1108
# exctrating data in batch1109
# exctrating data in batch1110
# exctrating data in batch1111
# exctrating data in batch1112
# exctrating data in batch1113
# exctrating data in batch1114
# exctrating data in batch1115
# exctrating data in batch1116
# exctrating data in batch1117
# exctrating data in batch1118
# exctrating data in batch1119
# exctrating data in batch1120
# exctrating data in batch1121
# exctrating data in batch1122
# exctrating data in batch1123
# exctrating data in batch1124
# exctrating data in batch1125
# exctrating data in batch1126
# exctrating data in batch1127
# exctrating data in batch1128
# exctrating data in batch1129
# exctrating data in batch1130
# exctrating data in batch1131
# exctrating data in batch1132
# exctrating data in batch1133
# exctrating data in batch1134
# exctrating data in batch1135
# exctrating data in batch1136
# exctrating data in batch1137
# exctrating data in batch1138
# exctrating data in batch1139
# exctrating data in batch1140
# exctrating data in batch1141
# exctrating data in batch1142
# exctrating data in batch1143
# exctrating data in batch1144
# exctrating data in batch1145
# exctrating data in batch1146
# exctrating data in batch1147
# exctrating data in batch1148
# exctrating data in batch1149
# exctrating data in batch1150
# exctrating data in batch1151
# exctrating data in batch1152
# exctrating data in batch1153
# exctrating data in batch1154
# exctrating data in batch1155
# exctrating data in batch1156
# exctrating data in batch1157
# exctrating data in batch1158
# exctrating data in batch1159
# exctrating data in batch1160
# exctrating data in batch1161
# exctrating data in batch1162
# exctrating data in batch1163
# exctrating data in batch1164
# exctrating data in batch1165
# exctrating data in batch1166
# exctrating data in batch1167
# exctrating data in batch1168
# exctrating data in batch1169
# exctrating data in batch1170
# exctrating data in batch1171
# exctrating data in batch1172
# exctrating data in batch1173
# exctrating data in batch1174
# exctrating data in batch1175
# exctrating data in batch1176
# exctrating data in batch1177
# exctrating data in batch1178
# exctrating data in batch1179
# exctrating data in batch1180
# exctrating data in batch1181
# exctrating data in batch1182
# exctrating data in batch1183
# exctrating data in batch1184
# exctrating data in batch1185
# exctrating data in batch1186
# exctrating data in batch1187
# exctrating data in batch1188
# exctrating data in batch1189
# exctrating data in batch1190
# exctrating data in batch1191
# exctrating data in batch1192
# exctrating data in batch1193
# exctrating data in batch1194
# exctrating data in batch1195
# exctrating data in batch1196
# exctrating data in batch1197
# exctrating data in batch1198
# exctrating data in batch1199
# exctrating data in batch1200
# exctrating data in batch1201
# exctrating data in batch1202
# exctrating data in batch1203
# exctrating data in batch1204
# exctrating data in batch1205
# exctrating data in batch1206
# exctrating data in batch1207
# exctrating data in batch1208
# exctrating data in batch1209
# exctrating data in batch1210
# exctrating data in batch1211
# exctrating data in batch1212
# exctrating data in batch1213
# exctrating data in batch1214
# exctrating data in batch1215
# exctrating data in batch1216
# exctrating data in batch1217
# exctrating data in batch1218
# exctrating data in batch1219
# exctrating data in batch1220
# exctrating data in batch1221
# exctrating data in batch1222
# exctrating data in batch1223
# exctrating data in batch1224
# exctrating data in batch1225
# exctrating data in batch1226
# exctrating data in batch1227
# exctrating data in batch1228
# exctrating data in batch1229
# exctrating data in batch1230
# exctrating data in batch1231
# exctrating data in batch1232
# exctrating data in batch1233
# exctrating data in batch1234
# exctrating data in batch1235
# exctrating data in batch1236
# exctrating data in batch1237
# exctrating data in batch1238
# exctrating data in batch1239
# exctrating data in batch1240
# exctrating data in batch1241
# exctrating data in batch1242
# exctrating data in batch1243
# exctrating data in batch1244
# exctrating data in batch1245
# exctrating data in batch1246
# exctrating data in batch1247
# exctrating data in batch1248
# exctrating data in batch1249
# exctrating data in batch1250
# exctrating data in batch1251
# exctrating data in batch1252
# exctrating data in batch1253
# exctrating data in batch1254
# exctrating data in batch1255
# exctrating data in batch1256
# exctrating data in batch1257
# exctrating data in batch1258
# exctrating data in batch1259
# exctrating data in batch1260
# exctrating data in batch1261
# exctrating data in batch1262
# exctrating data in batch1263
# exctrating data in batch1264
# exctrating data in batch1265
# exctrating data in batch1266
# exctrating data in batch1267
# exctrating data in batch1268
# exctrating data in batch1269
# exctrating data in batch1270
# exctrating data in batch1271
# exctrating data in batch1272
# exctrating data in batch1273
# exctrating data in batch1274
# exctrating data in batch1275
# exctrating data in batch1276
# exctrating data in batch1277
# exctrating data in batch1278
# exctrating data in batch1279
# exctrating data in batch1280
# exctrating data in batch1281
# exctrating data in batch1282
# exctrating data in batch1283
# exctrating data in batch1284
# exctrating data in batch1285
# exctrating data in batch1286
# exctrating data in batch1287
# exctrating data in batch1288
# exctrating data in batch1289
# exctrating data in batch1290
# exctrating data in batch1291
# exctrating data in batch1292
# exctrating data in batch1293
# exctrating data in batch1294
# exctrating data in batch1295
# exctrating data in batch1296
# exctrating data in batch1297
# exctrating data in batch1298
# exctrating data in batch1299
# exctrating data in batch1300
# exctrating data in batch1301
# exctrating data in batch1302
# exctrating data in batch1303
# exctrating data in batch1304
# exctrating data in batch1305
# exctrating data in batch1306
# exctrating data in batch1307
# exctrating data in batch1308
# exctrating data in batch1309
# exctrating data in batch1310
# exctrating data in batch1311
# exctrating data in batch1312
# exctrating data in batch1313
# exctrating data in batch1314
# exctrating data in batch1315
# exctrating data in batch1316
# exctrating data in batch1317
# exctrating data in batch1318
# exctrating data in batch1319
# exctrating data in batch1320
# exctrating data in batch1321
# exctrating data in batch1322
# exctrating data in batch1323
# exctrating data in batch1324
# exctrating data in batch1325
# exctrating data in batch1326
# exctrating data in batch1327
# exctrating data in batch1328
# exctrating data in batch1329
# exctrating data in batch1330
# exctrating data in batch1331
# exctrating data in batch1332
# exctrating data in batch1333
# exctrating data in batch1334
# exctrating data in batch1335
# exctrating data in batch1336
# exctrating data in batch1337
# exctrating data in batch1338
# exctrating data in batch1339
# exctrating data in batch1340
# exctrating data in batch1341
# exctrating data in batch1342
# exctrating data in batch1343
# exctrating data in batch1344
# exctrating data in batch1345
# exctrating data in batch1346
# exctrating data in batch1347
# exctrating data in batch1348
# exctrating data in batch1349
# exctrating data in batch1350
# exctrating data in batch1351
# exctrating data in batch1352
# exctrating data in batch1353
# exctrating data in batch1354
# exctrating data in batch1355
# exctrating data in batch1356
# exctrating data in batch1357
# exctrating data in batch1358
# exctrating data in batch1359
# exctrating data in batch1360
# exctrating data in batch1361
# exctrating data in batch1362
# exctrating data in batch1363
# exctrating data in batch1364
# exctrating data in batch1365
# exctrating data in batch1366
# exctrating data in batch1367
# exctrating data in batch1368
# exctrating data in batch1369
# exctrating data in batch1370
# exctrating data in batch1371
# exctrating data in batch1372
# exctrating data in batch1373
# exctrating data in batch1374
# exctrating data in batch1375
# exctrating data in batch1376
# exctrating data in batch1377
# exctrating data in batch1378
# exctrating data in batch1379
# exctrating data in batch1380
# exctrating data in batch1381
# exctrating data in batch1382
# exctrating data in batch1383
# exctrating data in batch1384
# exctrating data in batch1385
# exctrating data in batch1386
# exctrating data in batch1387
# exctrating data in batch1388
# exctrating data in batch1389
# exctrating data in batch1390
# exctrating data in batch1391
# exctrating data in batch1392
# exctrating data in batch1393
# exctrating data in batch1394
# exctrating data in batch1395
# exctrating data in batch1396
# exctrating data in batch1397
# exctrating data in batch1398
# exctrating data in batch1399
# exctrating data in batch1400
# exctrating data in batch1401
# exctrating data in batch1402
# exctrating data in batch1403
# exctrating data in batch1404
# exctrating data in batch1405
# exctrating data in batch1406
# exctrating data in batch1407
# exctrating data in batch1408
# exctrating data in batch1409
# exctrating data in batch1410
# exctrating data in batch1411
# exctrating data in batch1412
# exctrating data in batch1413
# exctrating data in batch1414
# exctrating data in batch1415
# exctrating data in batch1416
# exctrating data in batch1417
# exctrating data in batch1418
# exctrating data in batch1419
# exctrating data in batch1420
# exctrating data in batch1421
# exctrating data in batch1422
# exctrating data in batch1423
# exctrating data in batch1424
# exctrating data in batch1425
# exctrating data in batch1426
# exctrating data in batch1427
# exctrating data in batch1428
# exctrating data in batch1429
# exctrating data in batch1430
# exctrating data in batch1431
# exctrating data in batch1432
# exctrating data in batch1433
# exctrating data in batch1434
# exctrating data in batch1435
# exctrating data in batch1436
# exctrating data in batch1437
# exctrating data in batch1438
# exctrating data in batch1439
# exctrating data in batch1440
# exctrating data in batch1441
# exctrating data in batch1442
# exctrating data in batch1443
# exctrating data in batch1444
# exctrating data in batch1445
# exctrating data in batch1446
# exctrating data in batch1447
# exctrating data in batch1448
# exctrating data in batch1449
# exctrating data in batch1450
# exctrating data in batch1451
# exctrating data in batch1452
# exctrating data in batch1453
# exctrating data in batch1454
# exctrating data in batch1455
# exctrating data in batch1456
# exctrating data in batch1457
# exctrating data in batch1458
# exctrating data in batch1459
# exctrating data in batch1460
# exctrating data in batch1461
# exctrating data in batch1462
# exctrating data in batch1463
# exctrating data in batch1464
# exctrating data in batch1465
# exctrating data in batch1466
# exctrating data in batch1467
# exctrating data in batch1468
# exctrating data in batch1469
# exctrating data in batch1470
# exctrating data in batch1471
# exctrating data in batch1472
# exctrating data in batch1473
# exctrating data in batch1474
# exctrating data in batch1475
# exctrating data in batch1476
# exctrating data in batch1477
# exctrating data in batch1478
# exctrating data in batch1479
# exctrating data in batch1480
# exctrating data in batch1481
# exctrating data in batch1482
# exctrating data in batch1483
# exctrating data in batch1484
# exctrating data in batch1485
# exctrating data in batch1486
# exctrating data in batch1487
# exctrating data in batch1488
# exctrating data in batch1489
# exctrating data in batch1490
# exctrating data in batch1491
# exctrating data in batch1492
# exctrating data in batch1493
# exctrating data in batch1494
# exctrating data in batch1495
# exctrating data in batch1496
# exctrating data in batch1497
# exctrating data in batch1498
# exctrating data in batch1499
# exctrating data in batch1500
# exctrating data in batch1501
# exctrating data in batch1502
# exctrating data in batch1503
# exctrating data in batch1504
# exctrating data in batch1505
# exctrating data in batch1506
# exctrating data in batch1507
# exctrating data in batch1508
# exctrating data in batch1509
# exctrating data in batch1510
# exctrating data in batch1511
# exctrating data in batch1512
# exctrating data in batch1513
# exctrating data in batch1514
# exctrating data in batch1515
# exctrating data in batch1516
# exctrating data in batch1517
# exctrating data in batch1518
# exctrating data in batch1519
# exctrating data in batch1520
# exctrating data in batch1521
# exctrating data in batch1522
# exctrating data in batch1523
# exctrating data in batch1524
# exctrating data in batch1525
# exctrating data in batch1526
# exctrating data in batch1527
# exctrating data in batch1528
# exctrating data in batch1529
# exctrating data in batch1530
# exctrating data in batch1531
# exctrating data in batch1532
# exctrating data in batch1533
# exctrating data in batch1534
# exctrating data in batch1535
# exctrating data in batch1536
# exctrating data in batch1537
# exctrating data in batch1538
# exctrating data in batch1539
# exctrating data in batch1540
# exctrating data in batch1541
# exctrating data in batch1542
# exctrating data in batch1543
# exctrating data in batch1544
# exctrating data in batch1545
# exctrating data in batch1546
# exctrating data in batch1547
# exctrating data in batch1548
# exctrating data in batch1549
# exctrating data in batch1550
# exctrating data in batch1551
# exctrating data in batch1552
# exctrating data in batch1553
# exctrating data in batch1554
# exctrating data in batch1555
# exctrating data in batch1556
# exctrating data in batch1557
# exctrating data in batch1558
# exctrating data in batch1559
# exctrating data in batch1560
# exctrating data in batch1561
# exctrating data in batch1562
# exctrating data in batch1563
# exctrating data in batch1564
# exctrating data in batch1565
# exctrating data in batch1566
# exctrating data in batch1567
# exctrating data in batch1568
# exctrating data in batch1569
# exctrating data in batch1570
# exctrating data in batch1571
# exctrating data in batch1572
# exctrating data in batch1573
# exctrating data in batch1574
# exctrating data in batch1575
# exctrating data in batch1576
# exctrating data in batch1577
# exctrating data in batch1578
# exctrating data in batch1579
# exctrating data in batch1580
# exctrating data in batch1581
# exctrating data in batch1582
# exctrating data in batch1583
# exctrating data in batch1584
# exctrating data in batch1585
# exctrating data in batch1586
# exctrating data in batch1587
# exctrating data in batch1588
# exctrating data in batch1589
# exctrating data in batch1590
# exctrating data in batch1591
# exctrating data in batch1592
# exctrating data in batch1593
# exctrating data in batch1594
# exctrating data in batch1595
# exctrating data in batch1596
# exctrating data in batch1597
# exctrating data in batch1598
# exctrating data in batch1599
# exctrating data in batch1600
# exctrating data in batch1601
# exctrating data in batch1602
# exctrating data in batch1603
# exctrating data in batch1604
# exctrating data in batch1605
# exctrating data in batch1606
# exctrating data in batch1607
# exctrating data in batch1608
# exctrating data in batch1609
# exctrating data in batch1610
# exctrating data in batch1611
# exctrating data in batch1612
# exctrating data in batch1613
# exctrating data in batch1614
# exctrating data in batch1615
# exctrating data in batch1616
# exctrating data in batch1617
# exctrating data in batch1618
# exctrating data in batch1619
# exctrating data in batch1620
# exctrating data in batch1621
# exctrating data in batch1622
# exctrating data in batch1623
# exctrating data in batch1624
# exctrating data in batch1625
# exctrating data in batch1626
# exctrating data in batch1627
# exctrating data in batch1628
# exctrating data in batch1629
# exctrating data in batch1630
# exctrating data in batch1631
# exctrating data in batch1632
# exctrating data in batch1633
# exctrating data in batch1634
# exctrating data in batch1635
# exctrating data in batch1636
# exctrating data in batch1637
# exctrating data in batch1638
# exctrating data in batch1639
# exctrating data in batch1640
# exctrating data in batch1641
# exctrating data in batch1642
# exctrating data in batch1643
# exctrating data in batch1644
# exctrating data in batch1645
# exctrating data in batch1646
# exctrating data in batch1647
# exctrating data in batch1648
# exctrating data in batch1649
# exctrating data in batch1650
# exctrating data in batch1651
# exctrating data in batch1652
# exctrating data in batch1653
# exctrating data in batch1654
# exctrating data in batch1655
# exctrating data in batch1656
# exctrating data in batch1657
# exctrating data in batch1658
# exctrating data in batch1659
# exctrating data in batch1660
# exctrating data in batch1661
# exctrating data in batch1662
# exctrating data in batch1663
# exctrating data in batch1664
# exctrating data in batch1665
# exctrating data in batch1666
# exctrating data in batch1667
# exctrating data in batch1668
# exctrating data in batch1669
# exctrating data in batch1670
# exctrating data in batch1671
# exctrating data in batch1672
# exctrating data in batch1673
# exctrating data in batch1674
# exctrating data in batch1675
# exctrating data in batch1676
# exctrating data in batch1677
# exctrating data in batch1678
# exctrating data in batch1679
# exctrating data in batch1680
# exctrating data in batch1681
# exctrating data in batch1682
# exctrating data in batch1683
# exctrating data in batch1684
# exctrating data in batch1685
# exctrating data in batch1686
# exctrating data in batch1687
# exctrating data in batch1688
# exctrating data in batch1689
# exctrating data in batch1690
# exctrating data in batch1691
# exctrating data in batch1692
# exctrating data in batch1693
# exctrating data in batch1694
# exctrating data in batch1695
# exctrating data in batch1696
# exctrating data in batch1697
# exctrating data in batch1698
# exctrating data in batch1699
# exctrating data in batch1700
# exctrating data in batch1701
# exctrating data in batch1702
# exctrating data in batch1703
# exctrating data in batch1704
# exctrating data in batch1705
# exctrating data in batch1706
# exctrating data in batch1707
# exctrating data in batch1708
# exctrating data in batch1709
# exctrating data in batch1710
# exctrating data in batch1711
# exctrating data in batch1712
# exctrating data in batch1713
# exctrating data in batch1714
# exctrating data in batch1715
# exctrating data in batch1716
# exctrating data in batch1717
# exctrating data in batch1718
# exctrating data in batch1719
# exctrating data in batch1720
# exctrating data in batch1721
# exctrating data in batch1722
# exctrating data in batch1723
# exctrating data in batch1724
# exctrating data in batch1725
# exctrating data in batch1726
# exctrating data in batch1727
# exctrating data in batch1728
# exctrating data in batch1729
# exctrating data in batch1730
# exctrating data in batch1731
# exctrating data in batch1732
# exctrating data in batch1733
# exctrating data in batch1734
# exctrating data in batch1735
# exctrating data in batch1736
# exctrating data in batch1737
# exctrating data in batch1738
# exctrating data in batch1739
# exctrating data in batch1740
# exctrating data in batch1741
# exctrating data in batch1742
# exctrating data in batch1743
# exctrating data in batch1744
# exctrating data in batch1745
# exctrating data in batch1746
# exctrating data in batch1747
# exctrating data in batch1748
# exctrating data in batch1749
# exctrating data in batch1750
# exctrating data in batch1751
# exctrating data in batch1752
# exctrating data in batch1753
# exctrating data in batch1754
# exctrating data in batch1755
# exctrating data in batch1756
# exctrating data in batch1757
# exctrating data in batch1758
# exctrating data in batch1759
# exctrating data in batch1760
# exctrating data in batch1761

# %%
test_ext_1 = []
test_ext_2 = []
#for (data, target, name) in train_loader:
for batch_i, (data, target) in enumerate(test_loader):
#     if batch_i == 20:
#         break
    print(f'exctrating data in batch{batch_i}')
    data = data.cuda()
    model_conv_ext.cuda()
    output = model_conv_ext(data)
    for i in range(len(output)):
        test_ext_1.append((output[i].cpu().detach().numpy(),target[i]))
        test_ext_2.append((data[i].cpu().detach().numpy(),target[i]))

# %%
x = np.zeros((len(ext_1), 16384))
for i in range(len(ext_1)):
    x[i, :]= ext_1[i][0].reshape(1, 16384)
x_ts = np.zeros((len(test_ext_1), 16384))
for i in range(len(test_ext_1)):
    x[i, :]= test_ext_1[i][0].reshape(1, 16384)
y_n = np.argmax(y, axis = 1)
y_n_ts = np.argmax(y_ts, axis = 1)

# %% [markdown]
# ### Plot

# %%
len(train_df.values[0:999])
# Out:
# 999

# %% [markdown]
# ## Transfer Learning

# %%
class WhaleDataset(Dataset):
    def __init__(self, datafolder, datatype='train', df=None, transform = transforms.Compose([transforms.ToTensor()]), y=None):
        self.datafolder = datafolder
        self.datatype = datatype
        self.y = y
        if self.datatype == 'train':
            self.df = df.values
        self.image_files_list = [s for s in os.listdir(datafolder)]
        self.transform = transform


    def __len__(self):
        return len(self.image_files_list)
    
    def __getitem__(self, idx):
        if self.datatype == 'train':
            img_name = os.path.join(self.datafolder, self.df[idx - 1][0])
            label = self.y[idx - 1]
            
        elif self.datatype == 'test':
            img_name = os.path.join(self.datafolder, self.image_files_list[idx - 1])
            label = np.zeros((4571,))

        img = cv2.imread(img_name)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        image = self.transform(image=img)
        image = image['image']
        if self.datatype == 'train':
            return image, label
        elif self.datatype == 'test':
            # so that the images will be in a correct order
            return image, label, self.image_files_list[idx]

# %%
data_transforms = albumentations.Compose([
    albumentations.Resize(160, 320),
    albumentations.HorizontalFlip(),
    albumentations.RandomBrightness(),
    albumentations.ShiftScaleRotate(rotate_limit=15, scale_limit=0.10),
    albumentations.JpegCompression(80),
    albumentations.HueSaturationValue(),
    albumentations.Normalize(),
    AT.ToTensor()
    ])
data_transforms_test = albumentations.Compose([
    albumentations.Resize(160, 320),
    albumentations.Normalize(),
    AT.ToTensor()
    ])

train_dataset = WhaleDataset(datafolder='./whaletrain/', datatype='train', df=train_df, transform=data_transforms, y=y)
test_set = WhaleDataset(datafolder='./whaletest/', datatype='test', transform=data_transforms_test)

train_sampler = SubsetRandomSampler(list(range(len(os.listdir('./whaletrain')))))
valid_sampler = SubsetRandomSampler(list(range(len(os.listdir('./whaletest')))))
batch_size = 10

num_workers = 0
# prepare data loaders (combine dataset and sampler)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, sampler=train_sampler, num_workers=num_workers)
#valid_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, sampler=valid_sampler, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=10, num_workers=num_workers)

# %%
model_conv = pretrainedmodels.resnext101_64x4d()
model_conv.avg_pool = nn.AvgPool2d((5,10))
model_conv.last_linear = nn.Linear(model_conv.last_linear.in_features, 4571)

# %%
model_conv.cuda()
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model_conv.parameters(), lr=0.01)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)

# %%
from tqdm import tqdm_notebook, _tqdm_notebook
_tqdm_notebook.tqdm_notebook.pandas()
